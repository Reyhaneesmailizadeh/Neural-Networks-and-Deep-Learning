# %% [markdown]
# ## Homework2 \ question 2 - VGG16 backbone Augmented

# %% [markdown]
# ### importing dataset form drive

# %%
'''
from google.colab import drive
drive.mount('/content/drive')

# !unzip '/content/drive/My Drive/Q2 Dataset.zip' -d '/content/dataset'
'''
# Out:
# "\nfrom google.colab import drive\ndrive.mount('/content/drive')\n\n!unzip '/content/drive/My Drive/Q2 Dataset.zip' -d '/content/dataset'\n"

# %%
# !pip install gdown

url = 'https://drive.google.com/uc?id=1Pf0S5a7-3cNlhcvUDjv1JLXotjMleIgt'
output = '/content/Q2 Dataset.zip'

import gdown
gdown.download(url, output, quiet=False)

# !mkdir -p '/content/dataset/'
# Out:
# Requirement already satisfied: gdown in /usr/local/lib/python3.10/dist-packages (5.1.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from gdown) (4.12.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from gdown) (3.13.4)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.10/dist-packages (from gdown) (2.31.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from gdown) (4.66.2)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->gdown) (2.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (2024.2.2)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (1.7.1)
# Downloading...
# From: https://drive.google.com/uc?id=1Pf0S5a7-3cNlhcvUDjv1JLXotjMleIgt
# To: /content/Q2 Dataset.zip
# 100%|██████████| 18.4M/18.4M [00:00<00:00, 54.6MB/s]

# %%
# !unzip -q '/content/Q2 Dataset.zip' -d '/content/dataset/'

# %%
import numpy as np
import pandas as pd


# %matplotlib inline

import cv2
import matplotlib.pyplot as plt
import os

# %% [markdown]
# #### Defining hyperparams

# %%
NUM_CLASSES = 2

CHANNELS = 3

IMAGE_RESIZE = 224
RESNET50_POOLING_AVERAGE = 'avg'
DENSE_LAYER_ACTIVATION = 'softmax'
OBJECTIVE_FUNCTION = 'categorical_crossentropy'

LOSS_METRICS = ['accuracy']


NUM_CLASSES = 2  
IMAGE_RESIZE = 224
BATCH_SIZE_TRAINING = 10
BATCH_SIZE_VALIDATION = 10
NUM_EPOCHS = 50
STEPS_PER_EPOCH_TRAINING = 492 // BATCH_SIZE_TRAINING
STEPS_PER_EPOCH_VALIDATION = 210 // BATCH_SIZE_VALIDATION

BATCH_SIZE_TESTING = 1

# %%
from tensorflow.python.keras.models import Sequential
from tensorflow.python.keras.layers import Dense

# %%
ls
# Out:
#  dataset/  'Q2 Dataset.zip'   sample_data/

# %%
data_path = "/content/dataset/HW2_Dataset"

# %%
import tensorflow as tf

if tf.test.gpu_device_name():
    print('Default GPU Device:{}'.format(tf.test.gpu_device_name()))
else:
    print("Please install GPU version of TF")
# Out:
# Default GPU Device:/device:GPU:0

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
    except RuntimeError as e:
        print(e)

# %% [markdown]
# ## defining a functional model
# we replace the last fully connected network for our work

# %%
import tensorflow as tf
from tensorflow.keras.applications import VGG16
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout, Input, Flatten
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.callbacks import LearningRateScheduler


NUM_CLASSES = 2 

input_tensor = Input(shape=(224, 224, 3))
base_model = VGG16(include_top=False, weights='imagenet', input_tensor=input_tensor)


for layer in base_model.layers:
    layer.trainable = False
'''
# Unfreeze the last convolutional block
conv_block_layers = ['block5_conv1', 'block5_conv2', 'block5_conv3']
for layer in base_model.layers:
    if layer.name in conv_block_layers:
        layer.trainable = True
'''
x = Flatten()(base_model.output)
x = Dense(1024, activation='relu')(x)
x = Dropout(0.1)(x)  
outputs = Dense(NUM_CLASSES, activation='softmax')(x)

model = Model(inputs=input_tensor, outputs=outputs)


initial_lr = 0.001
decay_rate = 0.000002

# Define a learning rate scheduler
def scheduler(epoch, lr):
    """Learning rate schedule function that decreases the learning rate according to a decay rate."""
    return initial_lr * (1 / (1 + decay_rate * epoch))

# Set up the optimizer with initial learning rate and momentum
optimizer = SGD(learning_rate=initial_lr, momentum=0.9)

model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

# Learning rate scheduler callback
lr_scheduler = LearningRateScheduler(scheduler, verbose=1)

model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 1s 0us/step
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
#  flatten (Flatten)           (None, 25088)             0
#
#  dense (Dense)               (None, 1024)              25691136
#
#  dropout (Dropout)           (None, 1024)              0
#
#  dense_1 (Dense)             (None, 2)                 2050
#
# =================================================================
# Total params: 40407874 (154.14 MB)
# Trainable params: 25693186 (98.01 MB)
# Non-trainable params: 14714688 (56.13 MB)
# _________________________________________________________________

# %% [markdown]
# #### initializaing dataloaders
# For Augmented case

# %%
import tensorflow as tf
from tensorflow.keras.applications.resnet50 import preprocess_input
from tensorflow.keras.preprocessing.image import ImageDataGenerator

data_path = "/content/dataset/HW2_Dataset"  

if tf.test.gpu_device_name():
    print('Default GPU Device: {}'.format(tf.test.gpu_device_name()))
else:
    print("Please install GPU version of TF or check your TensorFlow GPU installation.")

gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
    except RuntimeError as e:
        print(e)


# Image data generator with preprocessing and augmentation for the training data
train_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input,
    rotation_range=30,  # Random rotation up to 30 degrees
    zoom_range=[0.75, 1.25],  # Scaling by zooming image in and out
    horizontal_flip=True,  # Horizontal flipping of images
    validation_split=0.3  # 30% of the data will be used for validation
)

# Training generator with data augmentation
train_generator = train_datagen.flow_from_directory(
    directory=f"{data_path}/Train",
    target_size=(IMAGE_RESIZE, IMAGE_RESIZE),
    batch_size=BATCH_SIZE_TRAINING,
    color_mode="rgb",
    class_mode="categorical",
    shuffle=True,
    subset='training'  # Set as training data
)

# Validation generator without data augmentation
valid_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input,
    validation_split=0.3  
)

valid_generator = valid_datagen.flow_from_directory(
    directory=f"{data_path}/Train",
    target_size=(IMAGE_RESIZE, IMAGE_RESIZE),
    batch_size=BATCH_SIZE_VALIDATION,
    color_mode="rgb",
    class_mode="categorical",
    shuffle=False,
    subset='validation'  
)

# Test generator, typically without augmentation
test_datagen = ImageDataGenerator(preprocessing_function=preprocess_input)
test_generator = test_datagen.flow_from_directory(
    directory=f"{data_path}/Test",
    target_size=(IMAGE_RESIZE, IMAGE_RESIZE),
    color_mode="rgb",
    batch_size=1,  
    class_mode="categorical",  
    shuffle=False,
    seed=42
)

print('Augmented')
# Out:
# Default GPU Device: /device:GPU:0
# Found 492 images belonging to 2 classes.
# Found 210 images belonging to 2 classes.
# Found 100 images belonging to 2 classes.
# Augmented

# %% [markdown]
# ### visualizing for Augmented case
# note: we use the denormalization (only) for visulizing after augmentation because the data loader already normalized our images.

# %%
import matplotlib.pyplot as plt
import numpy as np

x_batch, y_batch = next(train_generator)

def rescale_images(images):
    images = images - images.min()  
    images = images / images.max() 
    return images

x_batch = rescale_images(x_batch)

fig, axes = plt.subplots(1, 10, figsize=(20, 5))
for i in range(10):
    ax = axes[i]
    ax.imshow(x_batch[i])  
    ax.axis('off')
plt.show()

# %% [markdown]
# ### Dataloaders for the augmented case

# %%
(BATCH_SIZE_TRAINING, len(train_generator), BATCH_SIZE_VALIDATION, len(valid_generator))
# Out:
# (10, 50, 10, 21)

# %% [markdown]
# #### Training the model first time for the only last fully connected layer

# %%
from tensorflow.python.keras.callbacks import EarlyStopping, ModelCheckpoint

cb_checkpointer = ModelCheckpoint(filepath = '../working/best.hdf5', monitor = 'val_loss', save_best_only = True, mode = 'auto')

# %%
fit_history = model.fit(
        train_generator,
        steps_per_epoch=STEPS_PER_EPOCH_TRAINING,
        epochs = 50,
        validation_data=valid_generator,
        validation_steps=STEPS_PER_EPOCH_VALIDATION,
        callbacks = [LearningRateScheduler(scheduler, verbose=0), cb_checkpointer]
)
# Out:
# Epoch 1/50
# 49/49 [==============================] - ETA: 0s - loss: 18.1152 - accuracy: 0.8693
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 49/49 [==============================] - 29s 412ms/step - loss: 18.1152 - accuracy: 0.8693 - val_loss: 14.4264 - val_accuracy: 0.9667 - lr: 0.0010
# Epoch 2/50
# 49/49 [==============================] - 7s 149ms/step - loss: 96.4484 - accuracy: 0.8838 - val_loss: 24.5594 - val_accuracy: 0.9619 - lr: 1.0000e-03
# Epoch 3/50
# 49/49 [==============================] - 8s 166ms/step - loss: 139.0272 - accuracy: 0.9108 - val_loss: 364.1251 - val_accuracy: 0.9381 - lr: 1.0000e-03
# Epoch 4/50
# 49/49 [==============================] - 8s 167ms/step - loss: 350.4431 - accuracy: 0.9212 - val_loss: 161.9217 - val_accuracy: 0.9571 - lr: 9.9999e-04
# Epoch 5/50
# 49/49 [==============================] - 8s 153ms/step - loss: 1380.9434 - accuracy: 0.8983 - val_loss: 3224.2002 - val_accuracy: 0.9619 - lr: 9.9999e-04
# Epoch 6/50
# 49/49 [==============================] - 8s 159ms/step - loss: 2556.8740 - accuracy: 0.8817 - val_loss: 4068.3250 - val_accuracy: 0.8952 - lr: 9.9999e-04
# Epoch 7/50
# 49/49 [==============================] - 8s 170ms/step - loss: 9236.6846 - accuracy: 0.9149 - val_loss: 1723.4329 - val_accuracy: 0.9381 - lr: 9.9999e-04
# Epoch 8/50
# 49/49 [==============================] - 9s 173ms/step - loss: 8466.7314 - accuracy: 0.9000 - val_loss: 9083.9121 - val_accuracy: 0.9429 - lr: 9.9999e-04
# Epoch 9/50
# 49/49 [==============================] - 8s 156ms/step - loss: 5404.0796 - accuracy: 0.9357 - val_loss: 4368.9082 - val_accuracy: 0.9714 - lr: 9.9998e-04
# Epoch 10/50
# 49/49 [==============================] - 8s 152ms/step - loss: 4755.2915 - accuracy: 0.9502 - val_loss: 5684.5200 - val_accuracy: 0.9524 - lr: 9.9998e-04
# Epoch 11/50
# 49/49 [==============================] - 9s 180ms/step - loss: 2338.8071 - accuracy: 0.9315 - val_loss: 2011.6646 - val_accuracy: 0.9048 - lr: 9.9998e-04
# Epoch 12/50
# 49/49 [==============================] - 8s 169ms/step - loss: 4544.0181 - accuracy: 0.9108 - val_loss: 10569.3145 - val_accuracy: 0.9238 - lr: 9.9998e-04
# Epoch 13/50
# 49/49 [==============================] - 8s 154ms/step - loss: 12404.1934 - accuracy: 0.9170 - val_loss: 1540.5854 - val_accuracy: 0.9810 - lr: 9.9998e-04
# Epoch 14/50
# 49/49 [==============================] - 7s 150ms/step - loss: 55992.3711 - accuracy: 0.9170 - val_loss: 252549.1875 - val_accuracy: 0.9190 - lr: 9.9997e-04
# Epoch 15/50
# 49/49 [==============================] - 8s 154ms/step - loss: 74951.7812 - accuracy: 0.9253 - val_loss: 18652.1875 - val_accuracy: 0.9381 - lr: 9.9997e-04
# Epoch 16/50
# 49/49 [==============================] - 8s 171ms/step - loss: 29471.0195 - accuracy: 0.9295 - val_loss: 33212.3320 - val_accuracy: 0.9524 - lr: 9.9997e-04
# Epoch 17/50
# 49/49 [==============================] - 8s 168ms/step - loss: 1877.3584 - accuracy: 0.9502 - val_loss: 7561.7036 - val_accuracy: 0.9571 - lr: 9.9997e-04
# Epoch 18/50
# 49/49 [==============================] - 8s 153ms/step - loss: 3073.9050 - accuracy: 0.9440 - val_loss: 11980.1973 - val_accuracy: 0.9714 - lr: 9.9997e-04
# Epoch 19/50
# 49/49 [==============================] - 8s 156ms/step - loss: 27786.1055 - accuracy: 0.9232 - val_loss: 136600.2031 - val_accuracy: 0.8952 - lr: 9.9996e-04
# Epoch 20/50
# 49/49 [==============================] - 10s 195ms/step - loss: 48757.4414 - accuracy: 0.9232 - val_loss: 18205.6855 - val_accuracy: 0.9714 - lr: 9.9996e-04
# Epoch 21/50
# 49/49 [==============================] - 8s 172ms/step - loss: 58991.5938 - accuracy: 0.9336 - val_loss: 59378.1680 - val_accuracy: 0.9524 - lr: 9.9996e-04
# Epoch 22/50
# 49/49 [==============================] - 8s 156ms/step - loss: 83373.4922 - accuracy: 0.9336 - val_loss: 164987.4688 - val_accuracy: 0.9619 - lr: 9.9996e-04
# Epoch 23/50
# 49/49 [==============================] - 8s 154ms/step - loss: 28994.5977 - accuracy: 0.9544 - val_loss: 59592.9961 - val_accuracy: 0.9714 - lr: 9.9996e-04
# Epoch 24/50
# 49/49 [==============================] - 8s 152ms/step - loss: 77367.8828 - accuracy: 0.9191 - val_loss: 62496.5664 - val_accuracy: 0.9810 - lr: 9.9995e-04
# Epoch 25/50
# 49/49 [==============================] - 8s 156ms/step - loss: 14043.6904 - accuracy: 0.9419 - val_loss: 71383.6875 - val_accuracy: 0.9810 - lr: 9.9995e-04
# Epoch 26/50
# 49/49 [==============================] - 8s 171ms/step - loss: 32139.2773 - accuracy: 0.9481 - val_loss: 60556.6484 - val_accuracy: 0.9571 - lr: 9.9995e-04
# Epoch 27/50
# 49/49 [==============================] - 8s 171ms/step - loss: 1132.3588 - accuracy: 0.9585 - val_loss: 61000.5625 - val_accuracy: 0.9524 - lr: 9.9995e-04
# Epoch 28/50
# 49/49 [==============================] - 8s 157ms/step - loss: 8839.4863 - accuracy: 0.9551 - val_loss: 23204.2676 - val_accuracy: 0.9714 - lr: 9.9995e-04
# Epoch 29/50
# 49/49 [==============================] - 8s 170ms/step - loss: 15686.9541 - accuracy: 0.9212 - val_loss: 120757.7266 - val_accuracy: 0.9381 - lr: 9.9994e-04
# Epoch 30/50
# 49/49 [==============================] - 8s 168ms/step - loss: 47025.9883 - accuracy: 0.9544 - val_loss: 35617.4062 - val_accuracy: 0.9619 - lr: 9.9994e-04
# Epoch 31/50
# 49/49 [==============================] - 7s 151ms/step - loss: 13112.7969 - accuracy: 0.9544 - val_loss: 24532.8828 - val_accuracy: 0.9238 - lr: 9.9994e-04
# Epoch 32/50
# 49/49 [==============================] - 8s 154ms/step - loss: 2930.7791 - accuracy: 0.9378 - val_loss: 1534.6334 - val_accuracy: 0.9667 - lr: 9.9994e-04
# Epoch 33/50
# 49/49 [==============================] - 8s 171ms/step - loss: 1454.0530 - accuracy: 0.9440 - val_loss: 7666.6123 - val_accuracy: 0.9714 - lr: 9.9994e-04
# Epoch 34/50
# 49/49 [==============================] - 8s 171ms/step - loss: 5914.4985 - accuracy: 0.9357 - val_loss: 2257.4214 - val_accuracy: 0.9667 - lr: 9.9993e-04
# Epoch 35/50
# 49/49 [==============================] - 9s 184ms/step - loss: 3021.8833 - accuracy: 0.9481 - val_loss: 2282.1396 - val_accuracy: 0.9381 - lr: 9.9993e-04
# Epoch 36/50
# 49/49 [==============================] - 8s 154ms/step - loss: 664.3770 - accuracy: 0.9481 - val_loss: 5344.1528 - val_accuracy: 0.9571 - lr: 9.9993e-04
# Epoch 37/50
# 49/49 [==============================] - 8s 170ms/step - loss: 1313.4996 - accuracy: 0.9689 - val_loss: 2677.4199 - val_accuracy: 0.9524 - lr: 9.9993e-04
# Epoch 38/50
# 49/49 [==============================] - 8s 172ms/step - loss: 1925.1228 - accuracy: 0.9481 - val_loss: 2373.1809 - val_accuracy: 0.9571 - lr: 9.9993e-04
# Epoch 39/50
# 49/49 [==============================] - 8s 156ms/step - loss: 4988.9741 - accuracy: 0.9461 - val_loss: 3776.5623 - val_accuracy: 0.9667 - lr: 9.9992e-04
# Epoch 40/50
# 49/49 [==============================] - 7s 152ms/step - loss: 1344.7551 - accuracy: 0.9544 - val_loss: 556.2692 - val_accuracy: 0.9524 - lr: 9.9992e-04
# Epoch 41/50
# 49/49 [==============================] - 8s 173ms/step - loss: 821.0739 - accuracy: 0.9523 - val_loss: 49.9280 - val_accuracy: 0.9619 - lr: 9.9992e-04
# Epoch 42/50
# 49/49 [==============================] - 8s 172ms/step - loss: 192.8425 - accuracy: 0.9606 - val_loss: 38.3890 - val_accuracy: 0.9762 - lr: 9.9992e-04
# Epoch 43/50
# 49/49 [==============================] - 8s 171ms/step - loss: 111.9466 - accuracy: 0.9730 - val_loss: 107.7005 - val_accuracy: 0.9524 - lr: 9.9992e-04
# Epoch 44/50
# 49/49 [==============================] - 7s 152ms/step - loss: 27.1954 - accuracy: 0.9606 - val_loss: 49.0830 - val_accuracy: 0.9476 - lr: 9.9991e-04
# Epoch 45/50
# 49/49 [==============================] - 8s 174ms/step - loss: 3995.7766 - accuracy: 0.9502 - val_loss: 29.8888 - val_accuracy: 0.9667 - lr: 9.9991e-04
# Epoch 46/50
# 49/49 [==============================] - 8s 172ms/step - loss: 621.4739 - accuracy: 0.9461 - val_loss: 86.9414 - val_accuracy: 0.9619 - lr: 9.9991e-04
# Epoch 47/50
# 49/49 [==============================] - 8s 168ms/step - loss: 2914.1265 - accuracy: 0.9751 - val_loss: 893.4797 - val_accuracy: 0.9667 - lr: 9.9991e-04
# Epoch 48/50
# 49/49 [==============================] - 8s 157ms/step - loss: 0.1952 - accuracy: 0.9710 - val_loss: 2661.3982 - val_accuracy: 0.9714 - lr: 9.9991e-04
# Epoch 49/50
# 49/49 [==============================] - 8s 168ms/step - loss: 1993.6265 - accuracy: 0.9689 - val_loss: 2667.5361 - val_accuracy: 0.9714 - lr: 9.9990e-04
# Epoch 50/50
# 49/49 [==============================] - 8s 159ms/step - loss: 685.9400 - accuracy: 0.9523 - val_loss: 62.9678 - val_accuracy: 0.9619 - lr: 9.9990e-04

# %%
import matplotlib.pyplot as plt

plt.figure(1, figsize=(15, 8))

plt.subplot(221)
plt.plot(fit_history.history['accuracy'])  
plt.plot(fit_history.history['val_accuracy'])  
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

plt.subplot(222)
plt.plot(fit_history.history['loss'])
plt.plot(fit_history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.ylim(0,0.01)
plt.show()

# %%
import tensorflow as tf
from tensorflow.keras.applications import VGG16
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout, Input, Flatten
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.callbacks import LearningRateScheduler

NUM_CLASSES = 2  

input_tensor = Input(shape=(224, 224, 3))
base_model = VGG16(include_top=False, weights='imagenet', input_tensor=input_tensor)

for layer in base_model.layers:
    layer.trainable = False

layers_to_train = ['block5_conv1', 'block5_conv2', 'block5_conv3']

for layer in base_model.layers:
    if layer.name in layers_to_train:
        layer.trainable = True

x = Flatten()(base_model.output)
x = Dense(1024, activation='relu')(x)
x = Dropout(0.1)(x)  
outputs = Dense(NUM_CLASSES, activation='softmax')(x)

model2 = Model(inputs=input_tensor, outputs=outputs)

model2.load_weights('../working/best.hdf5')

outputs.trainable = True

initial_lr = 0.00001
decay_rate = 0.00000002

# Define a learning rate scheduler
def scheduler(epoch, lr):
    """Learning rate schedule function that decreases the learning rate according to a decay rate."""
    return initial_lr * (1 / (1 + decay_rate * epoch))

# Set up the optimizer with initial learning rate and momentum
optimizer = SGD(learning_rate=initial_lr, momentum=0.9)

model2.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

# Learning rate scheduler callback
lr_scheduler = LearningRateScheduler(scheduler, verbose=1)

model2.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
#  flatten_1 (Flatten)         (None, 25088)             0
#
#  dense_2 (Dense)             (None, 1024)              25691136
#
#  dropout_1 (Dropout)         (None, 1024)              0
#
#  dense_3 (Dense)             (None, 2)                 2050
#
# =================================================================
# Total params: 40407874 (154.14 MB)
# Trainable params: 32772610 (125.02 MB)
# Non-trainable params: 7635264 (29.13 MB)
# _________________________________________________________________

# %%
# List all trainable layers in the model
print("Trainable Layers:")
for layer in model2.layers:
    if layer.trainable:
        print(f"- {layer.name}")
# Out:
# Trainable Layers:
# - block5_conv1
# - block5_conv2
# - block5_conv3
# - flatten_1
# - dense_2
# - dropout_1
# - dense_3

# %%
# List all non-trainable layers in the model
print("Non-Trainable Layers:")
for layer in model2.layers:
    if not layer.trainable:
        print(f"- {layer.name}")
# Out:
# Non-Trainable Layers:
# - input_2
# - block1_conv1
# - block1_conv2
# - block1_pool
# - block2_conv1
# - block2_conv2
# - block2_pool
# - block3_conv1
# - block3_conv2
# - block3_conv3
# - block3_pool
# - block4_conv1
# - block4_conv2
# - block4_conv3
# - block4_pool
# - block5_pool

# %%
from tensorflow.python.keras.callbacks import EarlyStopping, ModelCheckpoint

cb_checkpointer2 = ModelCheckpoint(filepath = '../working/best2.hdf5', monitor = 'val_loss', save_best_only = True, mode = 'auto')

# %%
fit_history = model2.fit(
        train_generator,
        steps_per_epoch=STEPS_PER_EPOCH_TRAINING,
        epochs = 50,
        validation_data=valid_generator,
        validation_steps=STEPS_PER_EPOCH_VALIDATION,
        callbacks = [LearningRateScheduler(scheduler, verbose=0), cb_checkpointer2]
)
# Out:
# Epoch 1/50
# 49/49 [==============================] - 15s 270ms/step - loss: 10.7124 - accuracy: 0.8880 - val_loss: 2.2281 - val_accuracy: 0.9238 - lr: 1.0000e-05
# Epoch 2/50
# 49/49 [==============================] - 9s 184ms/step - loss: 1.0939 - accuracy: 0.8921 - val_loss: 1.3606 - val_accuracy: 0.9190 - lr: 1.0000e-05
# Epoch 3/50
# 49/49 [==============================] - 9s 177ms/step - loss: 0.5537 - accuracy: 0.9212 - val_loss: 0.9641 - val_accuracy: 0.9333 - lr: 1.0000e-05
# Epoch 4/50
# 49/49 [==============================] - 9s 187ms/step - loss: 0.7338 - accuracy: 0.9295 - val_loss: 0.6103 - val_accuracy: 0.9286 - lr: 1.0000e-05
# Epoch 5/50
# 49/49 [==============================] - 9s 176ms/step - loss: 0.1479 - accuracy: 0.9461 - val_loss: 0.7420 - val_accuracy: 0.9429 - lr: 1.0000e-05
# Epoch 6/50
# 49/49 [==============================] - 8s 163ms/step - loss: 0.1335 - accuracy: 0.9647 - val_loss: 1.5300 - val_accuracy: 0.9667 - lr: 1.0000e-05
# Epoch 7/50
# 49/49 [==============================] - 8s 155ms/step - loss: 0.0971 - accuracy: 0.9730 - val_loss: 1.4378 - val_accuracy: 0.9571 - lr: 1.0000e-05
# Epoch 8/50
# 49/49 [==============================] - 9s 175ms/step - loss: 0.2369 - accuracy: 0.9793 - val_loss: 1.5789 - val_accuracy: 0.9429 - lr: 1.0000e-05
# Epoch 9/50
# 49/49 [==============================] - 8s 160ms/step - loss: 0.1248 - accuracy: 0.9668 - val_loss: 1.2997 - val_accuracy: 0.9429 - lr: 1.0000e-05
# Epoch 10/50
# 49/49 [==============================] - 8s 161ms/step - loss: 0.1123 - accuracy: 0.9813 - val_loss: 1.1043 - val_accuracy: 0.9524 - lr: 1.0000e-05
# Epoch 11/50
# 49/49 [==============================] - 9s 174ms/step - loss: 0.0725 - accuracy: 0.9855 - val_loss: 1.0633 - val_accuracy: 0.9524 - lr: 1.0000e-05
# Epoch 12/50
# 49/49 [==============================] - 8s 160ms/step - loss: 0.0809 - accuracy: 0.9751 - val_loss: 1.2005 - val_accuracy: 0.9524 - lr: 1.0000e-05
# Epoch 13/50
# 49/49 [==============================] - 8s 158ms/step - loss: 0.1060 - accuracy: 0.9813 - val_loss: 1.5849 - val_accuracy: 0.9429 - lr: 1.0000e-05
# Epoch 14/50
# 49/49 [==============================] - 9s 174ms/step - loss: 0.0651 - accuracy: 0.9855 - val_loss: 1.3064 - val_accuracy: 0.9571 - lr: 1.0000e-05
# Epoch 15/50
# 49/49 [==============================] - 9s 174ms/step - loss: 0.1677 - accuracy: 0.9813 - val_loss: 1.4961 - val_accuracy: 0.9667 - lr: 1.0000e-05
# Epoch 16/50
# 49/49 [==============================] - 8s 156ms/step - loss: 0.0418 - accuracy: 0.9896 - val_loss: 1.0355 - val_accuracy: 0.9524 - lr: 1.0000e-05
# Epoch 17/50
# 49/49 [==============================] - 8s 173ms/step - loss: 0.0447 - accuracy: 0.9834 - val_loss: 1.0940 - val_accuracy: 0.9524 - lr: 1.0000e-05
# Epoch 18/50
# 49/49 [==============================] - 9s 175ms/step - loss: 0.0897 - accuracy: 0.9876 - val_loss: 1.4632 - val_accuracy: 0.9619 - lr: 1.0000e-05
# Epoch 19/50
# 49/49 [==============================] - 9s 191ms/step - loss: 0.0818 - accuracy: 0.9793 - val_loss: 1.0637 - val_accuracy: 0.9524 - lr: 1.0000e-05
# Epoch 20/50
# 49/49 [==============================] - 8s 156ms/step - loss: 0.0319 - accuracy: 0.9959 - val_loss: 1.1219 - val_accuracy: 0.9524 - lr: 1.0000e-05
# Epoch 21/50
# 49/49 [==============================] - 8s 173ms/step - loss: 0.0254 - accuracy: 0.9938 - val_loss: 1.1581 - val_accuracy: 0.9619 - lr: 1.0000e-05
# Epoch 22/50
# 49/49 [==============================] - 9s 175ms/step - loss: 0.0516 - accuracy: 0.9793 - val_loss: 0.9985 - val_accuracy: 0.9619 - lr: 1.0000e-05
# Epoch 23/50
# 49/49 [==============================] - 8s 159ms/step - loss: 0.0314 - accuracy: 0.9917 - val_loss: 0.9655 - val_accuracy: 0.9619 - lr: 1.0000e-05
# Epoch 24/50
# 49/49 [==============================] - 8s 159ms/step - loss: 0.1276 - accuracy: 0.9813 - val_loss: 0.8712 - val_accuracy: 0.9571 - lr: 1.0000e-05
# Epoch 25/50
# 49/49 [==============================] - 8s 158ms/step - loss: 0.0470 - accuracy: 0.9938 - val_loss: 0.8393 - val_accuracy: 0.9619 - lr: 1.0000e-05
# Epoch 26/50
# 49/49 [==============================] - 9s 175ms/step - loss: 0.0260 - accuracy: 0.9896 - val_loss: 0.8027 - val_accuracy: 0.9619 - lr: 1.0000e-05
# Epoch 27/50
# 49/49 [==============================] - 8s 171ms/step - loss: 0.0611 - accuracy: 0.9855 - val_loss: 0.9219 - val_accuracy: 0.9571 - lr: 1.0000e-05
# Epoch 28/50
# 49/49 [==============================] - 8s 158ms/step - loss: 0.0818 - accuracy: 0.9855 - val_loss: 0.7283 - val_accuracy: 0.9667 - lr: 1.0000e-05
# Epoch 29/50
# 49/49 [==============================] - 9s 178ms/step - loss: 0.0034 - accuracy: 0.9979 - val_loss: 0.7467 - val_accuracy: 0.9667 - lr: 1.0000e-05
# Epoch 30/50
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0375 - accuracy: 0.9917 - val_loss: 0.7505 - val_accuracy: 0.9619 - lr: 1.0000e-05
# Epoch 31/50
# 49/49 [==============================] - 8s 172ms/step - loss: 0.0090 - accuracy: 0.9938 - val_loss: 0.7589 - val_accuracy: 0.9667 - lr: 1.0000e-05
# Epoch 32/50
# 49/49 [==============================] - 8s 158ms/step - loss: 0.0131 - accuracy: 0.9938 - val_loss: 0.8137 - val_accuracy: 0.9619 - lr: 1.0000e-05
# Epoch 33/50
# 49/49 [==============================] - 9s 175ms/step - loss: 0.0555 - accuracy: 0.9855 - val_loss: 0.8224 - val_accuracy: 0.9619 - lr: 1.0000e-05
# Epoch 34/50
# 49/49 [==============================] - 9s 177ms/step - loss: 0.0406 - accuracy: 0.9876 - val_loss: 0.8033 - val_accuracy: 0.9714 - lr: 1.0000e-05
# Epoch 35/50
# 49/49 [==============================] - 8s 157ms/step - loss: 0.0375 - accuracy: 0.9917 - val_loss: 0.9226 - val_accuracy: 0.9619 - lr: 1.0000e-05
# Epoch 36/50
# 49/49 [==============================] - 8s 156ms/step - loss: 0.0493 - accuracy: 0.9917 - val_loss: 0.9678 - val_accuracy: 0.9619 - lr: 1.0000e-05
# Epoch 37/50
# 49/49 [==============================] - 9s 175ms/step - loss: 0.0238 - accuracy: 0.9938 - val_loss: 1.0200 - val_accuracy: 0.9667 - lr: 1.0000e-05
# Epoch 38/50
# 49/49 [==============================] - 9s 176ms/step - loss: 0.0202 - accuracy: 0.9959 - val_loss: 1.0131 - val_accuracy: 0.9667 - lr: 1.0000e-05
# Epoch 39/50
# 49/49 [==============================] - 8s 156ms/step - loss: 0.0082 - accuracy: 0.9979 - val_loss: 1.0581 - val_accuracy: 0.9667 - lr: 1.0000e-05
# Epoch 40/50
# 49/49 [==============================] - 8s 165ms/step - loss: 0.0040 - accuracy: 0.9979 - val_loss: 1.0853 - val_accuracy: 0.9667 - lr: 1.0000e-05
# Epoch 41/50
# 49/49 [==============================] - 9s 175ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 1.0904 - val_accuracy: 0.9667 - lr: 1.0000e-05
# Epoch 42/50
# 49/49 [==============================] - 9s 176ms/step - loss: 7.9400e-04 - accuracy: 1.0000 - val_loss: 1.0831 - val_accuracy: 0.9667 - lr: 1.0000e-05
# Epoch 43/50
# 49/49 [==============================] - 8s 155ms/step - loss: 0.0164 - accuracy: 0.9979 - val_loss: 1.3065 - val_accuracy: 0.9571 - lr: 1.0000e-05
# Epoch 44/50
# 49/49 [==============================] - 8s 159ms/step - loss: 0.0193 - accuracy: 0.9938 - val_loss: 1.2092 - val_accuracy: 0.9714 - lr: 1.0000e-05
# Epoch 45/50
# 49/49 [==============================] - 9s 175ms/step - loss: 0.0140 - accuracy: 0.9938 - val_loss: 1.4588 - val_accuracy: 0.9619 - lr: 1.0000e-05
# Epoch 46/50
# 49/49 [==============================] - 8s 173ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 1.5046 - val_accuracy: 0.9619 - lr: 1.0000e-05
# Epoch 47/50
# 49/49 [==============================] - 8s 158ms/step - loss: 0.0081 - accuracy: 0.9959 - val_loss: 1.5481 - val_accuracy: 0.9619 - lr: 1.0000e-05
# Epoch 48/50
# 49/49 [==============================] - 8s 160ms/step - loss: 0.0104 - accuracy: 0.9979 - val_loss: 1.4987 - val_accuracy: 0.9667 - lr: 1.0000e-05
# Epoch 49/50
# 49/49 [==============================] - 9s 174ms/step - loss: 0.0045 - accuracy: 0.9979 - val_loss: 1.3670 - val_accuracy: 0.9714 - lr: 1.0000e-05
# Epoch 50/50
# 49/49 [==============================] - 8s 173ms/step - loss: 0.0072 - accuracy: 0.9979 - val_loss: 1.3143 - val_accuracy: 0.9714 - lr: 1.0000e-05

# %%
model2.save('../working/full_model.h5')

# %%
print(fit_history.history.keys())
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])

# %% [markdown]
# ## Visualizing final model train-dev set ouput

# %%
import matplotlib.pyplot as plt

plt.figure(1, figsize=(15, 8))

plt.subplot(221)
plt.plot(fit_history.history['accuracy'])  
plt.plot(fit_history.history['val_accuracy']) 
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.ylim(0.7,1.01)

plt.subplot(222)
plt.plot(fit_history.history['loss'])
plt.plot(fit_history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.ylim(0,15)

plt.show()

# %%
ls
# Out:
#  dataset/  'Q2 Dataset.zip'   sample_data/

# %% [markdown]
# ### Test set accuracy

# %%
test_generator.reset()
pred = model2.predict(test_generator, steps=np.ceil(len(test_generator.filenames) / BATCH_SIZE_TESTING), verbose=1)

predicted_class_indices = np.argmax(pred, axis=1) if pred.shape[-1] > 1 else (pred > 0.5).astype('int32')

true_class_indices = test_generator.classes

# Calculate accuracy
correct_predictions = np.sum(predicted_class_indices == true_class_indices)
total_predictions = len(predicted_class_indices)
test_accuracy = correct_predictions / total_predictions

print(f"Test Accuracy: {test_accuracy:.2f}")
# Out:
# 100/100 [==============================] - 2s 9ms/step
# Test Accuracy: 0.96

# %% [markdown]
# ## Accuracy and confustion matrix of the resultant network

# %%
from sklearn.metrics import confusion_matrix, classification_report

cm = confusion_matrix(true_class_indices, predicted_class_indices)
print("Confusion Matrix:\n", cm)

report = classification_report(true_class_indices, predicted_class_indices, target_names=['Class1', 'Class2'])
print("\nClassification Report:\n", report)
# Out:
# Confusion Matrix:
#  [[47  3]
#  [ 1 49]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#       Class1       0.98      0.94      0.96        50
#       Class2       0.94      0.98      0.96        50
#
#     accuracy                           0.96       100
#    macro avg       0.96      0.96      0.96       100
# weighted avg       0.96      0.96      0.96       100

# %% [markdown]
# ## Visualizing for testing case

# %%
import cv2
import matplotlib.pyplot as plt
import os

data_path = "/content/dataset/HW2_Dataset"
TEST_DIR = f"{data_path}/Test"
num_images = 25  

f, ax = plt.subplots(5, 5, figsize=(15, 15), subplot_kw={'xticks': [], 'yticks': [], 'frame_on': True})

for i in range(25):
    img_path = os.path.join(TEST_DIR, test_generator.filenames[i+35])
    imgBGR = cv2.imread(img_path)
    if imgBGR is None:
        print("Failed to load image at:", img_path)
        continue  

    imgRGB = cv2.cvtColor(imgBGR, cv2.COLOR_BGR2RGB)
    true_class_indices = test_generator.classes

    predicted_class = "Dog" if predicted_class_indices[i+35] == 1 else "Cat"
    true_class = "Dog" if true_class_indices[i+35] == 1 else "Cat"
    is_correct = predicted_class == true_class

    edge_color = 'green' if is_correct else 'red'
    title_color = 'green' if is_correct else 'red'  

    ax[i // 5, i % 5].imshow(imgRGB)
    ax[i // 5, i % 5].set_frame_on(True)
    ax[i // 5, i % 5].spines['bottom'].set_color(edge_color)
    ax[i // 5, i % 5].spines['top'].set_color(edge_color)
    ax[i // 5, i % 5].spines['right'].set_color(edge_color)
    ax[i // 5, i % 5].spines['left'].set_color(edge_color)
    ax[i // 5, i % 5].spines['bottom'].set_linewidth(5)
    ax[i // 5, i % 5].spines['top'].set_linewidth(5)
    ax[i // 5, i % 5].spines['right'].set_linewidth(5)
    ax[i // 5, i % 5].spines['left'].set_linewidth(5)
    ax[i // 5, i % 5].axis('off')
    ax[i // 5, i % 5].set_title(f"Predicted: {predicted_class}", color=title_color)

f.subplots_adjust(hspace=0.5)

plt.show()

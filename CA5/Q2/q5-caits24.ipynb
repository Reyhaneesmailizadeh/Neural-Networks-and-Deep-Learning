# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
from torchvision import models
import time
import matplotlib.pyplot as plt

transform_train = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize((0.485, 0.456, 0.406), (0.229, 0.224, 0.225)), 
])

transform_test = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize((0.485, 0.456, 0.406), (0.229, 0.224, 0.225)),  
])

trainset = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=transform_train)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=8, shuffle=True, num_workers=2)

testset = torchvision.datasets.CIFAR10(root='./data', train=False, download=True, transform=transform_test)
testloader = torch.utils.data.DataLoader(testset, batch_size=8, shuffle=False, num_workers=2)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
# !pip install torchsummary
# Out:
# Requirement already satisfied: torchsummary in /opt/conda/lib/python3.10/site-packages (1.5.1)

# %%
# !pip install timm
# Out:
# Requirement already satisfied: timm in /opt/conda/lib/python3.10/site-packages (1.0.3)
# Requirement already satisfied: torch in /opt/conda/lib/python3.10/site-packages (from timm) (2.1.2)
# Requirement already satisfied: torchvision in /opt/conda/lib/python3.10/site-packages (from timm) (0.16.2)
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.10/site-packages (from timm) (6.0.1)
# Requirement already satisfied: huggingface_hub in /opt/conda/lib/python3.10/site-packages (from timm) (0.23.2)
# Requirement already satisfied: safetensors in /opt/conda/lib/python3.10/site-packages (from timm) (0.4.3)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from huggingface_hub->timm) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/conda/lib/python3.10/site-packages (from huggingface_hub->timm) (2024.3.1)
# Requirement already satisfied: packaging>=20.9 in /opt/conda/lib/python3.10/site-packages (from huggingface_hub->timm) (21.3)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from huggingface_hub->timm) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in /opt/conda/lib/python3.10/site-packages (from huggingface_hub->timm) (4.66.4)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/conda/lib/python3.10/site-packages (from huggingface_hub->timm) (4.9.0)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch->timm) (1.12.1)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch->timm) (3.2.1)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch->timm) (3.1.2)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from torchvision->timm) (1.26.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /opt/conda/lib/python3.10/site-packages (from torchvision->timm) (9.5.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging>=20.9->huggingface_hub->timm) (3.1.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch->timm) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface_hub->timm) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface_hub->timm) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface_hub->timm) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface_hub->timm) (2024.2.2)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from sympy->torch->timm) (1.3.0)

# %%
import torch
import timm
import torch.nn as nn
import torchvision.models as models
from torchsummary import summary
from torch.optim.lr_scheduler import ReduceLROnPlateau

import warnings

warnings.filterwarnings("ignore")

model = timm.create_model('cait_s24_224', pretrained=True)

for name, param in model.named_parameters():
    if 'blocks.23' in name:  
        param.requires_grad = True
    else:
        param.requires_grad = False

model.head = nn.Linear(model.head.in_features, 10)

model.classifier = nn.Sequential(
    nn.Linear(model.head.in_features, 256),
    nn.ELU(),
    nn.Dropout(0.5),
    nn.Linear(256, 10),
)


device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)

summary(model, (3, 224, 224))

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.0001)
scheduler = ReduceLROnPlateau(optimizer, mode='max', factor=0.6, patience=3, verbose=True, min_lr=1e-7)



print("\nLayer status:")
for name, param in model.named_parameters():
    print(f"{name}: requires_grad={param.requires_grad}")
# Out:
# model.safetensors:   0%|          | 0.00/188M [00:00<?, ?B/s]
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1          [-1, 384, 14, 14]         295,296
#           Identity-2             [-1, 196, 384]               0
#         PatchEmbed-3             [-1, 196, 384]               0
#            Dropout-4             [-1, 196, 384]               0
#          LayerNorm-5             [-1, 196, 384]             768
#             Linear-6            [-1, 196, 1152]         443,520
#             Linear-7          [-1, 196, 196, 8]              72
#             Linear-8          [-1, 196, 196, 8]              72
#            Dropout-9          [-1, 8, 196, 196]               0
#            Linear-10             [-1, 196, 384]         147,840
#           Dropout-11             [-1, 196, 384]               0
#   TalkingHeadAttn-12             [-1, 196, 384]               0
#          Identity-13             [-1, 196, 384]               0
#         LayerNorm-14             [-1, 196, 384]             768
#            Linear-15            [-1, 196, 1536]         591,360
#              GELU-16            [-1, 196, 1536]               0
#           Dropout-17            [-1, 196, 1536]               0
#          Identity-18            [-1, 196, 1536]               0
#            Linear-19             [-1, 196, 384]         590,208
#           Dropout-20             [-1, 196, 384]               0
#               Mlp-21             [-1, 196, 384]               0
#          Identity-22             [-1, 196, 384]               0
#   LayerScaleBlock-23             [-1, 196, 384]               0
#         LayerNorm-24             [-1, 196, 384]             768
#            Linear-25            [-1, 196, 1152]         443,520
#            Linear-26          [-1, 196, 196, 8]              72
#            Linear-27          [-1, 196, 196, 8]              72
#           Dropout-28          [-1, 8, 196, 196]               0
#            Linear-29             [-1, 196, 384]         147,840
#           Dropout-30             [-1, 196, 384]               0
#   TalkingHeadAttn-31             [-1, 196, 384]               0
#          Identity-32             [-1, 196, 384]               0
#         LayerNorm-33             [-1, 196, 384]             768
#            Linear-34            [-1, 196, 1536]         591,360
#              GELU-35            [-1, 196, 1536]               0
#           Dropout-36            [-1, 196, 1536]               0
#          Identity-37            [-1, 196, 1536]               0
#            Linear-38             [-1, 196, 384]         590,208
#           Dropout-39             [-1, 196, 384]               0
#               Mlp-40             [-1, 196, 384]               0
#          Identity-41             [-1, 196, 384]               0
#   LayerScaleBlock-42             [-1, 196, 384]               0
#         LayerNorm-43             [-1, 196, 384]             768
#            Linear-44            [-1, 196, 1152]         443,520
#            Linear-45          [-1, 196, 196, 8]              72
#            Linear-46          [-1, 196, 196, 8]              72
#           Dropout-47          [-1, 8, 196, 196]               0
#            Linear-48             [-1, 196, 384]         147,840
#           Dropout-49             [-1, 196, 384]               0
#   TalkingHeadAttn-50             [-1, 196, 384]               0
#          Identity-51             [-1, 196, 384]               0
#         LayerNorm-52             [-1, 196, 384]             768
#            Linear-53            [-1, 196, 1536]         591,360
#              GELU-54            [-1, 196, 1536]               0
#           Dropout-55            [-1, 196, 1536]               0
#          Identity-56            [-1, 196, 1536]               0
#            Linear-57             [-1, 196, 384]         590,208
#           Dropout-58             [-1, 196, 384]               0
#               Mlp-59             [-1, 196, 384]               0
#          Identity-60             [-1, 196, 384]               0
#   LayerScaleBlock-61             [-1, 196, 384]               0
#         LayerNorm-62             [-1, 196, 384]             768
#            Linear-63            [-1, 196, 1152]         443,520
#            Linear-64          [-1, 196, 196, 8]              72
#            Linear-65          [-1, 196, 196, 8]              72
#           Dropout-66          [-1, 8, 196, 196]               0
#            Linear-67             [-1, 196, 384]         147,840
#           Dropout-68             [-1, 196, 384]               0
#   TalkingHeadAttn-69             [-1, 196, 384]               0
#          Identity-70             [-1, 196, 384]               0
#         LayerNorm-71             [-1, 196, 384]             768
#            Linear-72            [-1, 196, 1536]         591,360
#              GELU-73            [-1, 196, 1536]               0
#           Dropout-74            [-1, 196, 1536]               0
#          Identity-75            [-1, 196, 1536]               0
#            Linear-76             [-1, 196, 384]         590,208
#           Dropout-77             [-1, 196, 384]               0
#               Mlp-78             [-1, 196, 384]               0
#          Identity-79             [-1, 196, 384]               0
#   LayerScaleBlock-80             [-1, 196, 384]               0
#         LayerNorm-81             [-1, 196, 384]             768
#            Linear-82            [-1, 196, 1152]         443,520
#            Linear-83          [-1, 196, 196, 8]              72
#            Linear-84          [-1, 196, 196, 8]              72
#           Dropout-85          [-1, 8, 196, 196]               0
#            Linear-86             [-1, 196, 384]         147,840
#           Dropout-87             [-1, 196, 384]               0
#   TalkingHeadAttn-88             [-1, 196, 384]               0
#          Identity-89             [-1, 196, 384]               0
#         LayerNorm-90             [-1, 196, 384]             768
#            Linear-91            [-1, 196, 1536]         591,360
#              GELU-92            [-1, 196, 1536]               0
#           Dropout-93            [-1, 196, 1536]               0
#          Identity-94            [-1, 196, 1536]               0
#            Linear-95             [-1, 196, 384]         590,208
#           Dropout-96             [-1, 196, 384]               0
#               Mlp-97             [-1, 196, 384]               0
#          Identity-98             [-1, 196, 384]               0
#   LayerScaleBlock-99             [-1, 196, 384]               0
#        LayerNorm-100             [-1, 196, 384]             768
#           Linear-101            [-1, 196, 1152]         443,520
#           Linear-102          [-1, 196, 196, 8]              72
#           Linear-103          [-1, 196, 196, 8]              72
#          Dropout-104          [-1, 8, 196, 196]               0
#           Linear-105             [-1, 196, 384]         147,840
#          Dropout-106             [-1, 196, 384]               0
#  TalkingHeadAttn-107             [-1, 196, 384]               0
#         Identity-108             [-1, 196, 384]               0
#        LayerNorm-109             [-1, 196, 384]             768
#           Linear-110            [-1, 196, 1536]         591,360
#             GELU-111            [-1, 196, 1536]               0
#          Dropout-112            [-1, 196, 1536]               0
#         Identity-113            [-1, 196, 1536]               0
#           Linear-114             [-1, 196, 384]         590,208
#          Dropout-115             [-1, 196, 384]               0
#              Mlp-116             [-1, 196, 384]               0
#         Identity-117             [-1, 196, 384]               0
#  LayerScaleBlock-118             [-1, 196, 384]               0
#        LayerNorm-119             [-1, 196, 384]             768
#           Linear-120            [-1, 196, 1152]         443,520
#           Linear-121          [-1, 196, 196, 8]              72
#           Linear-122          [-1, 196, 196, 8]              72
#          Dropout-123          [-1, 8, 196, 196]               0
#           Linear-124             [-1, 196, 384]         147,840
#          Dropout-125             [-1, 196, 384]               0
#  TalkingHeadAttn-126             [-1, 196, 384]               0
#         Identity-127             [-1, 196, 384]               0
#        LayerNorm-128             [-1, 196, 384]             768
#           Linear-129            [-1, 196, 1536]         591,360
#             GELU-130            [-1, 196, 1536]               0
#          Dropout-131            [-1, 196, 1536]               0
#         Identity-132            [-1, 196, 1536]               0
#           Linear-133             [-1, 196, 384]         590,208
#          Dropout-134             [-1, 196, 384]               0
#              Mlp-135             [-1, 196, 384]               0
#         Identity-136             [-1, 196, 384]               0
#  LayerScaleBlock-137             [-1, 196, 384]               0
#        LayerNorm-138             [-1, 196, 384]             768
#           Linear-139            [-1, 196, 1152]         443,520
#           Linear-140          [-1, 196, 196, 8]              72
#           Linear-141          [-1, 196, 196, 8]              72
#          Dropout-142          [-1, 8, 196, 196]               0
#           Linear-143             [-1, 196, 384]         147,840
#          Dropout-144             [-1, 196, 384]               0
#  TalkingHeadAttn-145             [-1, 196, 384]               0
#         Identity-146             [-1, 196, 384]               0
#        LayerNorm-147             [-1, 196, 384]             768
#           Linear-148            [-1, 196, 1536]         591,360
#             GELU-149            [-1, 196, 1536]               0
#          Dropout-150            [-1, 196, 1536]               0
#         Identity-151            [-1, 196, 1536]               0
#           Linear-152             [-1, 196, 384]         590,208
#          Dropout-153             [-1, 196, 384]               0
#              Mlp-154             [-1, 196, 384]               0
#         Identity-155             [-1, 196, 384]               0
#  LayerScaleBlock-156             [-1, 196, 384]               0
#        LayerNorm-157             [-1, 196, 384]             768
#           Linear-158            [-1, 196, 1152]         443,520
#           Linear-159          [-1, 196, 196, 8]              72
#           Linear-160          [-1, 196, 196, 8]              72
#          Dropout-161          [-1, 8, 196, 196]               0
#           Linear-162             [-1, 196, 384]         147,840
#          Dropout-163             [-1, 196, 384]               0
#  TalkingHeadAttn-164             [-1, 196, 384]               0
#         Identity-165             [-1, 196, 384]               0
#        LayerNorm-166             [-1, 196, 384]             768
#           Linear-167            [-1, 196, 1536]         591,360
#             GELU-168            [-1, 196, 1536]               0
#          Dropout-169            [-1, 196, 1536]               0
#         Identity-170            [-1, 196, 1536]               0
#           Linear-171             [-1, 196, 384]         590,208
#          Dropout-172             [-1, 196, 384]               0
#              Mlp-173             [-1, 196, 384]               0
#         Identity-174             [-1, 196, 384]               0
#  LayerScaleBlock-175             [-1, 196, 384]               0
#        LayerNorm-176             [-1, 196, 384]             768
#           Linear-177            [-1, 196, 1152]         443,520
#           Linear-178          [-1, 196, 196, 8]              72
#           Linear-179          [-1, 196, 196, 8]              72
#          Dropout-180          [-1, 8, 196, 196]               0
#           Linear-181             [-1, 196, 384]         147,840
#          Dropout-182             [-1, 196, 384]               0
#  TalkingHeadAttn-183             [-1, 196, 384]               0
#         Identity-184             [-1, 196, 384]               0
#        LayerNorm-185             [-1, 196, 384]             768
#           Linear-186            [-1, 196, 1536]         591,360
#             GELU-187            [-1, 196, 1536]               0
#          Dropout-188            [-1, 196, 1536]               0
#         Identity-189            [-1, 196, 1536]               0
#           Linear-190             [-1, 196, 384]         590,208
#          Dropout-191             [-1, 196, 384]               0
#              Mlp-192             [-1, 196, 384]               0
#         Identity-193             [-1, 196, 384]               0
#  LayerScaleBlock-194             [-1, 196, 384]               0
#        LayerNorm-195             [-1, 196, 384]             768
#           Linear-196            [-1, 196, 1152]         443,520
#           Linear-197          [-1, 196, 196, 8]              72
#           Linear-198          [-1, 196, 196, 8]              72
#          Dropout-199          [-1, 8, 196, 196]               0
#           Linear-200             [-1, 196, 384]         147,840
#          Dropout-201             [-1, 196, 384]               0
#  TalkingHeadAttn-202             [-1, 196, 384]               0
#         Identity-203             [-1, 196, 384]               0
#        LayerNorm-204             [-1, 196, 384]             768
#           Linear-205            [-1, 196, 1536]         591,360
#             GELU-206            [-1, 196, 1536]               0
#          Dropout-207            [-1, 196, 1536]               0
#         Identity-208            [-1, 196, 1536]               0
#           Linear-209             [-1, 196, 384]         590,208
#          Dropout-210             [-1, 196, 384]               0
#              Mlp-211             [-1, 196, 384]               0
#         Identity-212             [-1, 196, 384]               0
#  LayerScaleBlock-213             [-1, 196, 384]               0
#        LayerNorm-214             [-1, 196, 384]             768
#           Linear-215            [-1, 196, 1152]         443,520
#           Linear-216          [-1, 196, 196, 8]              72
#           Linear-217          [-1, 196, 196, 8]              72
#          Dropout-218          [-1, 8, 196, 196]               0
#           Linear-219             [-1, 196, 384]         147,840
#          Dropout-220             [-1, 196, 384]               0
#  TalkingHeadAttn-221             [-1, 196, 384]               0
#         Identity-222             [-1, 196, 384]               0
#        LayerNorm-223             [-1, 196, 384]             768
#           Linear-224            [-1, 196, 1536]         591,360
#             GELU-225            [-1, 196, 1536]               0
#          Dropout-226            [-1, 196, 1536]               0
#         Identity-227            [-1, 196, 1536]               0
#           Linear-228             [-1, 196, 384]         590,208
#          Dropout-229             [-1, 196, 384]               0
#              Mlp-230             [-1, 196, 384]               0
#         Identity-231             [-1, 196, 384]               0
#  LayerScaleBlock-232             [-1, 196, 384]               0
#        LayerNorm-233             [-1, 196, 384]             768
#           Linear-234            [-1, 196, 1152]         443,520
#           Linear-235          [-1, 196, 196, 8]              72
#           Linear-236          [-1, 196, 196, 8]              72
#          Dropout-237          [-1, 8, 196, 196]               0
#           Linear-238             [-1, 196, 384]         147,840
#          Dropout-239             [-1, 196, 384]               0
#  TalkingHeadAttn-240             [-1, 196, 384]               0
#         Identity-241             [-1, 196, 384]               0
#        LayerNorm-242             [-1, 196, 384]             768
#           Linear-243            [-1, 196, 1536]         591,360
#             GELU-244            [-1, 196, 1536]               0
#          Dropout-245            [-1, 196, 1536]               0
#         Identity-246            [-1, 196, 1536]               0
#           Linear-247             [-1, 196, 384]         590,208
#          Dropout-248             [-1, 196, 384]               0
#              Mlp-249             [-1, 196, 384]               0
#         Identity-250             [-1, 196, 384]               0
#  LayerScaleBlock-251             [-1, 196, 384]               0
#        LayerNorm-252             [-1, 196, 384]             768
#           Linear-253            [-1, 196, 1152]         443,520
#           Linear-254          [-1, 196, 196, 8]              72
#           Linear-255          [-1, 196, 196, 8]              72
#          Dropout-256          [-1, 8, 196, 196]               0
#           Linear-257             [-1, 196, 384]         147,840
#          Dropout-258             [-1, 196, 384]               0
#  TalkingHeadAttn-259             [-1, 196, 384]               0
#         Identity-260             [-1, 196, 384]               0
#        LayerNorm-261             [-1, 196, 384]             768
#           Linear-262            [-1, 196, 1536]         591,360
#             GELU-263            [-1, 196, 1536]               0
#          Dropout-264            [-1, 196, 1536]               0
#         Identity-265            [-1, 196, 1536]               0
#           Linear-266             [-1, 196, 384]         590,208
#          Dropout-267             [-1, 196, 384]               0
#              Mlp-268             [-1, 196, 384]               0
#         Identity-269             [-1, 196, 384]               0
#  LayerScaleBlock-270             [-1, 196, 384]               0
#        LayerNorm-271             [-1, 196, 384]             768
#           Linear-272            [-1, 196, 1152]         443,520
#           Linear-273          [-1, 196, 196, 8]              72
#           Linear-274          [-1, 196, 196, 8]              72
#          Dropout-275          [-1, 8, 196, 196]               0
#           Linear-276             [-1, 196, 384]         147,840
#          Dropout-277             [-1, 196, 384]               0
#  TalkingHeadAttn-278             [-1, 196, 384]               0
#         Identity-279             [-1, 196, 384]               0
#        LayerNorm-280             [-1, 196, 384]             768
#           Linear-281            [-1, 196, 1536]         591,360
#             GELU-282            [-1, 196, 1536]               0
#          Dropout-283            [-1, 196, 1536]               0
#         Identity-284            [-1, 196, 1536]               0
#           Linear-285             [-1, 196, 384]         590,208
#          Dropout-286             [-1, 196, 384]               0
#              Mlp-287             [-1, 196, 384]               0
#         Identity-288             [-1, 196, 384]               0
#  LayerScaleBlock-289             [-1, 196, 384]               0
#        LayerNorm-290             [-1, 196, 384]             768
#           Linear-291            [-1, 196, 1152]         443,520
#           Linear-292          [-1, 196, 196, 8]              72
#           Linear-293          [-1, 196, 196, 8]              72
#          Dropout-294          [-1, 8, 196, 196]               0
#           Linear-295             [-1, 196, 384]         147,840
#          Dropout-296             [-1, 196, 384]               0
#  TalkingHeadAttn-297             [-1, 196, 384]               0
#         Identity-298             [-1, 196, 384]               0
#        LayerNorm-299             [-1, 196, 384]             768
#           Linear-300            [-1, 196, 1536]         591,360
#             GELU-301            [-1, 196, 1536]               0
#          Dropout-302            [-1, 196, 1536]               0
#         Identity-303            [-1, 196, 1536]               0
#           Linear-304             [-1, 196, 384]         590,208
#          Dropout-305             [-1, 196, 384]               0
#              Mlp-306             [-1, 196, 384]               0
#         Identity-307             [-1, 196, 384]               0
#  LayerScaleBlock-308             [-1, 196, 384]               0
#        LayerNorm-309             [-1, 196, 384]             768
#           Linear-310            [-1, 196, 1152]         443,520
#           Linear-311          [-1, 196, 196, 8]              72
#           Linear-312          [-1, 196, 196, 8]              72
#          Dropout-313          [-1, 8, 196, 196]               0
#           Linear-314             [-1, 196, 384]         147,840
#          Dropout-315             [-1, 196, 384]               0
#  TalkingHeadAttn-316             [-1, 196, 384]               0
#         Identity-317             [-1, 196, 384]               0
#        LayerNorm-318             [-1, 196, 384]             768
#           Linear-319            [-1, 196, 1536]         591,360
#             GELU-320            [-1, 196, 1536]               0
#          Dropout-321            [-1, 196, 1536]               0
#         Identity-322            [-1, 196, 1536]               0
#           Linear-323             [-1, 196, 384]         590,208
#          Dropout-324             [-1, 196, 384]               0
#              Mlp-325             [-1, 196, 384]               0
#         Identity-326             [-1, 196, 384]               0
#  LayerScaleBlock-327             [-1, 196, 384]               0
#        LayerNorm-328             [-1, 196, 384]             768
#           Linear-329            [-1, 196, 1152]         443,520
#           Linear-330          [-1, 196, 196, 8]              72
#           Linear-331          [-1, 196, 196, 8]              72
#          Dropout-332          [-1, 8, 196, 196]               0
#           Linear-333             [-1, 196, 384]         147,840
#          Dropout-334             [-1, 196, 384]               0
#  TalkingHeadAttn-335             [-1, 196, 384]               0
#         Identity-336             [-1, 196, 384]               0
#        LayerNorm-337             [-1, 196, 384]             768
#           Linear-338            [-1, 196, 1536]         591,360
#             GELU-339            [-1, 196, 1536]               0
#          Dropout-340            [-1, 196, 1536]               0
#         Identity-341            [-1, 196, 1536]               0
#           Linear-342             [-1, 196, 384]         590,208
#          Dropout-343             [-1, 196, 384]               0
#              Mlp-344             [-1, 196, 384]               0
#         Identity-345             [-1, 196, 384]               0
#  LayerScaleBlock-346             [-1, 196, 384]               0
#        LayerNorm-347             [-1, 196, 384]             768
#           Linear-348            [-1, 196, 1152]         443,520
#           Linear-349          [-1, 196, 196, 8]              72
#           Linear-350          [-1, 196, 196, 8]              72
#          Dropout-351          [-1, 8, 196, 196]               0
#           Linear-352             [-1, 196, 384]         147,840
#          Dropout-353             [-1, 196, 384]               0
#  TalkingHeadAttn-354             [-1, 196, 384]               0
#         Identity-355             [-1, 196, 384]               0
#        LayerNorm-356             [-1, 196, 384]             768
#           Linear-357            [-1, 196, 1536]         591,360
#             GELU-358            [-1, 196, 1536]               0
#          Dropout-359            [-1, 196, 1536]               0
#         Identity-360            [-1, 196, 1536]               0
#           Linear-361             [-1, 196, 384]         590,208
#          Dropout-362             [-1, 196, 384]               0
#              Mlp-363             [-1, 196, 384]               0
#         Identity-364             [-1, 196, 384]               0
#  LayerScaleBlock-365             [-1, 196, 384]               0
#        LayerNorm-366             [-1, 196, 384]             768
#           Linear-367            [-1, 196, 1152]         443,520
#           Linear-368          [-1, 196, 196, 8]              72
#           Linear-369          [-1, 196, 196, 8]              72
#          Dropout-370          [-1, 8, 196, 196]               0
#           Linear-371             [-1, 196, 384]         147,840
#          Dropout-372             [-1, 196, 384]               0
#  TalkingHeadAttn-373             [-1, 196, 384]               0
#         Identity-374             [-1, 196, 384]               0
#        LayerNorm-375             [-1, 196, 384]             768
#           Linear-376            [-1, 196, 1536]         591,360
#             GELU-377            [-1, 196, 1536]               0
#          Dropout-378            [-1, 196, 1536]               0
#         Identity-379            [-1, 196, 1536]               0
#           Linear-380             [-1, 196, 384]         590,208
#          Dropout-381             [-1, 196, 384]               0
#              Mlp-382             [-1, 196, 384]               0
#         Identity-383             [-1, 196, 384]               0
#  LayerScaleBlock-384             [-1, 196, 384]               0
#        LayerNorm-385             [-1, 196, 384]             768
#           Linear-386            [-1, 196, 1152]         443,520
#           Linear-387          [-1, 196, 196, 8]              72
#           Linear-388          [-1, 196, 196, 8]              72
#          Dropout-389          [-1, 8, 196, 196]               0
#           Linear-390             [-1, 196, 384]         147,840
#          Dropout-391             [-1, 196, 384]               0
#  TalkingHeadAttn-392             [-1, 196, 384]               0
#         Identity-393             [-1, 196, 384]               0
#        LayerNorm-394             [-1, 196, 384]             768
#           Linear-395            [-1, 196, 1536]         591,360
#             GELU-396            [-1, 196, 1536]               0
#          Dropout-397            [-1, 196, 1536]               0
#         Identity-398            [-1, 196, 1536]               0
#           Linear-399             [-1, 196, 384]         590,208
#          Dropout-400             [-1, 196, 384]               0
#              Mlp-401             [-1, 196, 384]               0
#         Identity-402             [-1, 196, 384]               0
#  LayerScaleBlock-403             [-1, 196, 384]               0
#        LayerNorm-404             [-1, 196, 384]             768
#           Linear-405            [-1, 196, 1152]         443,520
#           Linear-406          [-1, 196, 196, 8]              72
#           Linear-407          [-1, 196, 196, 8]              72
#          Dropout-408          [-1, 8, 196, 196]               0
#           Linear-409             [-1, 196, 384]         147,840
#          Dropout-410             [-1, 196, 384]               0
#  TalkingHeadAttn-411             [-1, 196, 384]               0
#         Identity-412             [-1, 196, 384]               0
#        LayerNorm-413             [-1, 196, 384]             768
#           Linear-414            [-1, 196, 1536]         591,360
#             GELU-415            [-1, 196, 1536]               0
#          Dropout-416            [-1, 196, 1536]               0
#         Identity-417            [-1, 196, 1536]               0
#           Linear-418             [-1, 196, 384]         590,208
#          Dropout-419             [-1, 196, 384]               0
#              Mlp-420             [-1, 196, 384]               0
#         Identity-421             [-1, 196, 384]               0
#  LayerScaleBlock-422             [-1, 196, 384]               0
#        LayerNorm-423             [-1, 196, 384]             768
#           Linear-424            [-1, 196, 1152]         443,520
#           Linear-425          [-1, 196, 196, 8]              72
#           Linear-426          [-1, 196, 196, 8]              72
#          Dropout-427          [-1, 8, 196, 196]               0
#           Linear-428             [-1, 196, 384]         147,840
#          Dropout-429             [-1, 196, 384]               0
#  TalkingHeadAttn-430             [-1, 196, 384]               0
#         Identity-431             [-1, 196, 384]               0
#        LayerNorm-432             [-1, 196, 384]             768
#           Linear-433            [-1, 196, 1536]         591,360
#             GELU-434            [-1, 196, 1536]               0
#          Dropout-435            [-1, 196, 1536]               0
#         Identity-436            [-1, 196, 1536]               0
#           Linear-437             [-1, 196, 384]         590,208
#          Dropout-438             [-1, 196, 384]               0
#              Mlp-439             [-1, 196, 384]               0
#         Identity-440             [-1, 196, 384]               0
#  LayerScaleBlock-441             [-1, 196, 384]               0
#        LayerNorm-442             [-1, 196, 384]             768
#           Linear-443            [-1, 196, 1152]         443,520
#           Linear-444          [-1, 196, 196, 8]              72
#           Linear-445          [-1, 196, 196, 8]              72
#          Dropout-446          [-1, 8, 196, 196]               0
#           Linear-447             [-1, 196, 384]         147,840
#          Dropout-448             [-1, 196, 384]               0
#  TalkingHeadAttn-449             [-1, 196, 384]               0
#         Identity-450             [-1, 196, 384]               0
#        LayerNorm-451             [-1, 196, 384]             768
#           Linear-452            [-1, 196, 1536]         591,360
#             GELU-453            [-1, 196, 1536]               0
#          Dropout-454            [-1, 196, 1536]               0
#         Identity-455            [-1, 196, 1536]               0
#           Linear-456             [-1, 196, 384]         590,208
#          Dropout-457             [-1, 196, 384]               0
#              Mlp-458             [-1, 196, 384]               0
#         Identity-459             [-1, 196, 384]               0
#  LayerScaleBlock-460             [-1, 196, 384]               0
#        LayerNorm-461             [-1, 197, 384]             768
#           Linear-462                  [-1, 384]         147,840
#           Linear-463             [-1, 197, 384]         147,840
#           Linear-464             [-1, 197, 384]         147,840
#           Linear-465               [-1, 1, 384]         147,840
#          Dropout-466               [-1, 1, 384]               0
#        ClassAttn-467               [-1, 1, 384]               0
#         Identity-468               [-1, 1, 384]               0
#        LayerNorm-469               [-1, 1, 384]             768
#           Linear-470              [-1, 1, 1536]         591,360
#             GELU-471              [-1, 1, 1536]               0
#          Dropout-472              [-1, 1, 1536]               0
#         Identity-473              [-1, 1, 1536]               0
#           Linear-474               [-1, 1, 384]         590,208
#          Dropout-475               [-1, 1, 384]               0
#              Mlp-476               [-1, 1, 384]               0
#         Identity-477               [-1, 1, 384]               0
# LayerScaleBlockClassAttn-478               [-1, 1, 384]               0
#        LayerNorm-479             [-1, 197, 384]             768
#           Linear-480                  [-1, 384]         147,840
#           Linear-481             [-1, 197, 384]         147,840
#           Linear-482             [-1, 197, 384]         147,840
#           Linear-483               [-1, 1, 384]         147,840
#          Dropout-484               [-1, 1, 384]               0
#        ClassAttn-485               [-1, 1, 384]               0
#         Identity-486               [-1, 1, 384]               0
#        LayerNorm-487               [-1, 1, 384]             768
#           Linear-488              [-1, 1, 1536]         591,360
#             GELU-489              [-1, 1, 1536]               0
#          Dropout-490              [-1, 1, 1536]               0
#         Identity-491              [-1, 1, 1536]               0
#           Linear-492               [-1, 1, 384]         590,208
#          Dropout-493               [-1, 1, 384]               0
#              Mlp-494               [-1, 1, 384]               0
#         Identity-495               [-1, 1, 384]               0
# LayerScaleBlockClassAttn-496               [-1, 1, 384]               0
#        LayerNorm-497             [-1, 197, 384]             768
#          Dropout-498                  [-1, 384]               0
#           Linear-499                   [-1, 10]           3,850
# ================================================================
# Total params: 46,439,434
# Trainable params: 1,778,458
# Non-trainable params: 44,660,976
# ----------------------------------------------------------------
# Input size (MB): 0.57
# Forward/backward pass size (MB): 588.76
# Params size (MB): 177.15
# Estimated Total Size (MB): 766.48
# ----------------------------------------------------------------
#
# Layer status:
# cls_token: requires_grad=False
# pos_embed: requires_grad=False
# patch_embed.proj.weight: requires_grad=False
# patch_embed.proj.bias: requires_grad=False
# blocks.0.gamma_1: requires_grad=False
# blocks.0.gamma_2: requires_grad=False
# blocks.0.norm1.weight: requires_grad=False
# blocks.0.norm1.bias: requires_grad=False
# blocks.0.attn.qkv.weight: requires_grad=False
# blocks.0.attn.qkv.bias: requires_grad=False
# blocks.0.attn.proj.weight: requires_grad=False
# blocks.0.attn.proj.bias: requires_grad=False
# blocks.0.attn.proj_l.weight: requires_grad=False
# blocks.0.attn.proj_l.bias: requires_grad=False
# blocks.0.attn.proj_w.weight: requires_grad=False
# blocks.0.attn.proj_w.bias: requires_grad=False
# blocks.0.norm2.weight: requires_grad=False
# blocks.0.norm2.bias: requires_grad=False
# blocks.0.mlp.fc1.weight: requires_grad=False
# blocks.0.mlp.fc1.bias: requires_grad=False
# blocks.0.mlp.fc2.weight: requires_grad=False
# blocks.0.mlp.fc2.bias: requires_grad=False
# blocks.1.gamma_1: requires_grad=False
# blocks.1.gamma_2: requires_grad=False
# blocks.1.norm1.weight: requires_grad=False
# blocks.1.norm1.bias: requires_grad=False
# blocks.1.attn.qkv.weight: requires_grad=False
# blocks.1.attn.qkv.bias: requires_grad=False
# blocks.1.attn.proj.weight: requires_grad=False
# blocks.1.attn.proj.bias: requires_grad=False
# blocks.1.attn.proj_l.weight: requires_grad=False
# blocks.1.attn.proj_l.bias: requires_grad=False
# blocks.1.attn.proj_w.weight: requires_grad=False
# blocks.1.attn.proj_w.bias: requires_grad=False
# blocks.1.norm2.weight: requires_grad=False
# blocks.1.norm2.bias: requires_grad=False
# blocks.1.mlp.fc1.weight: requires_grad=False
# blocks.1.mlp.fc1.bias: requires_grad=False
# blocks.1.mlp.fc2.weight: requires_grad=False
# blocks.1.mlp.fc2.bias: requires_grad=False
# blocks.2.gamma_1: requires_grad=False
# blocks.2.gamma_2: requires_grad=False
# blocks.2.norm1.weight: requires_grad=False
# blocks.2.norm1.bias: requires_grad=False
# blocks.2.attn.qkv.weight: requires_grad=False
# blocks.2.attn.qkv.bias: requires_grad=False
# blocks.2.attn.proj.weight: requires_grad=False
# blocks.2.attn.proj.bias: requires_grad=False
# blocks.2.attn.proj_l.weight: requires_grad=False
# blocks.2.attn.proj_l.bias: requires_grad=False
# blocks.2.attn.proj_w.weight: requires_grad=False
# blocks.2.attn.proj_w.bias: requires_grad=False
# blocks.2.norm2.weight: requires_grad=False
# blocks.2.norm2.bias: requires_grad=False
# blocks.2.mlp.fc1.weight: requires_grad=False
# blocks.2.mlp.fc1.bias: requires_grad=False
# blocks.2.mlp.fc2.weight: requires_grad=False
# blocks.2.mlp.fc2.bias: requires_grad=False
# blocks.3.gamma_1: requires_grad=False
# blocks.3.gamma_2: requires_grad=False
# blocks.3.norm1.weight: requires_grad=False
# blocks.3.norm1.bias: requires_grad=False
# blocks.3.attn.qkv.weight: requires_grad=False
# blocks.3.attn.qkv.bias: requires_grad=False
# blocks.3.attn.proj.weight: requires_grad=False
# blocks.3.attn.proj.bias: requires_grad=False
# blocks.3.attn.proj_l.weight: requires_grad=False
# blocks.3.attn.proj_l.bias: requires_grad=False
# blocks.3.attn.proj_w.weight: requires_grad=False
# blocks.3.attn.proj_w.bias: requires_grad=False
# blocks.3.norm2.weight: requires_grad=False
# blocks.3.norm2.bias: requires_grad=False
# blocks.3.mlp.fc1.weight: requires_grad=False
# blocks.3.mlp.fc1.bias: requires_grad=False
# blocks.3.mlp.fc2.weight: requires_grad=False
# blocks.3.mlp.fc2.bias: requires_grad=False
# blocks.4.gamma_1: requires_grad=False
# blocks.4.gamma_2: requires_grad=False
# blocks.4.norm1.weight: requires_grad=False
# blocks.4.norm1.bias: requires_grad=False
# blocks.4.attn.qkv.weight: requires_grad=False
# blocks.4.attn.qkv.bias: requires_grad=False
# blocks.4.attn.proj.weight: requires_grad=False
# blocks.4.attn.proj.bias: requires_grad=False
# blocks.4.attn.proj_l.weight: requires_grad=False
# blocks.4.attn.proj_l.bias: requires_grad=False
# blocks.4.attn.proj_w.weight: requires_grad=False
# blocks.4.attn.proj_w.bias: requires_grad=False
# blocks.4.norm2.weight: requires_grad=False
# blocks.4.norm2.bias: requires_grad=False
# blocks.4.mlp.fc1.weight: requires_grad=False
# blocks.4.mlp.fc1.bias: requires_grad=False
# blocks.4.mlp.fc2.weight: requires_grad=False
# blocks.4.mlp.fc2.bias: requires_grad=False
# blocks.5.gamma_1: requires_grad=False
# blocks.5.gamma_2: requires_grad=False
# blocks.5.norm1.weight: requires_grad=False
# blocks.5.norm1.bias: requires_grad=False
# blocks.5.attn.qkv.weight: requires_grad=False
# blocks.5.attn.qkv.bias: requires_grad=False
# blocks.5.attn.proj.weight: requires_grad=False
# blocks.5.attn.proj.bias: requires_grad=False
# blocks.5.attn.proj_l.weight: requires_grad=False
# blocks.5.attn.proj_l.bias: requires_grad=False
# blocks.5.attn.proj_w.weight: requires_grad=False
# blocks.5.attn.proj_w.bias: requires_grad=False
# blocks.5.norm2.weight: requires_grad=False
# blocks.5.norm2.bias: requires_grad=False
# blocks.5.mlp.fc1.weight: requires_grad=False
# blocks.5.mlp.fc1.bias: requires_grad=False
# blocks.5.mlp.fc2.weight: requires_grad=False
# blocks.5.mlp.fc2.bias: requires_grad=False
# blocks.6.gamma_1: requires_grad=False
# blocks.6.gamma_2: requires_grad=False
# blocks.6.norm1.weight: requires_grad=False
# blocks.6.norm1.bias: requires_grad=False
# blocks.6.attn.qkv.weight: requires_grad=False
# blocks.6.attn.qkv.bias: requires_grad=False
# blocks.6.attn.proj.weight: requires_grad=False
# blocks.6.attn.proj.bias: requires_grad=False
# blocks.6.attn.proj_l.weight: requires_grad=False
# blocks.6.attn.proj_l.bias: requires_grad=False
# blocks.6.attn.proj_w.weight: requires_grad=False
# blocks.6.attn.proj_w.bias: requires_grad=False
# blocks.6.norm2.weight: requires_grad=False
# blocks.6.norm2.bias: requires_grad=False
# blocks.6.mlp.fc1.weight: requires_grad=False
# blocks.6.mlp.fc1.bias: requires_grad=False
# blocks.6.mlp.fc2.weight: requires_grad=False
# blocks.6.mlp.fc2.bias: requires_grad=False
# blocks.7.gamma_1: requires_grad=False
# blocks.7.gamma_2: requires_grad=False
# blocks.7.norm1.weight: requires_grad=False
# blocks.7.norm1.bias: requires_grad=False
# blocks.7.attn.qkv.weight: requires_grad=False
# blocks.7.attn.qkv.bias: requires_grad=False
# blocks.7.attn.proj.weight: requires_grad=False
# blocks.7.attn.proj.bias: requires_grad=False
# blocks.7.attn.proj_l.weight: requires_grad=False
# blocks.7.attn.proj_l.bias: requires_grad=False
# blocks.7.attn.proj_w.weight: requires_grad=False
# blocks.7.attn.proj_w.bias: requires_grad=False
# blocks.7.norm2.weight: requires_grad=False
# blocks.7.norm2.bias: requires_grad=False
# blocks.7.mlp.fc1.weight: requires_grad=False
# blocks.7.mlp.fc1.bias: requires_grad=False
# blocks.7.mlp.fc2.weight: requires_grad=False
# blocks.7.mlp.fc2.bias: requires_grad=False
# blocks.8.gamma_1: requires_grad=False
# blocks.8.gamma_2: requires_grad=False
# blocks.8.norm1.weight: requires_grad=False
# blocks.8.norm1.bias: requires_grad=False
# blocks.8.attn.qkv.weight: requires_grad=False
# blocks.8.attn.qkv.bias: requires_grad=False
# blocks.8.attn.proj.weight: requires_grad=False
# blocks.8.attn.proj.bias: requires_grad=False
# blocks.8.attn.proj_l.weight: requires_grad=False
# blocks.8.attn.proj_l.bias: requires_grad=False
# blocks.8.attn.proj_w.weight: requires_grad=False
# blocks.8.attn.proj_w.bias: requires_grad=False
# blocks.8.norm2.weight: requires_grad=False
# blocks.8.norm2.bias: requires_grad=False
# blocks.8.mlp.fc1.weight: requires_grad=False
# blocks.8.mlp.fc1.bias: requires_grad=False
# blocks.8.mlp.fc2.weight: requires_grad=False
# blocks.8.mlp.fc2.bias: requires_grad=False
# blocks.9.gamma_1: requires_grad=False
# blocks.9.gamma_2: requires_grad=False
# blocks.9.norm1.weight: requires_grad=False
# blocks.9.norm1.bias: requires_grad=False
# blocks.9.attn.qkv.weight: requires_grad=False
# blocks.9.attn.qkv.bias: requires_grad=False
# blocks.9.attn.proj.weight: requires_grad=False
# blocks.9.attn.proj.bias: requires_grad=False
# blocks.9.attn.proj_l.weight: requires_grad=False
# blocks.9.attn.proj_l.bias: requires_grad=False
# blocks.9.attn.proj_w.weight: requires_grad=False
# blocks.9.attn.proj_w.bias: requires_grad=False
# blocks.9.norm2.weight: requires_grad=False
# blocks.9.norm2.bias: requires_grad=False
# blocks.9.mlp.fc1.weight: requires_grad=False
# blocks.9.mlp.fc1.bias: requires_grad=False
# blocks.9.mlp.fc2.weight: requires_grad=False
# blocks.9.mlp.fc2.bias: requires_grad=False
# blocks.10.gamma_1: requires_grad=False
# blocks.10.gamma_2: requires_grad=False
# blocks.10.norm1.weight: requires_grad=False
# blocks.10.norm1.bias: requires_grad=False
# blocks.10.attn.qkv.weight: requires_grad=False
# blocks.10.attn.qkv.bias: requires_grad=False
# blocks.10.attn.proj.weight: requires_grad=False
# blocks.10.attn.proj.bias: requires_grad=False
# blocks.10.attn.proj_l.weight: requires_grad=False
# blocks.10.attn.proj_l.bias: requires_grad=False
# blocks.10.attn.proj_w.weight: requires_grad=False
# blocks.10.attn.proj_w.bias: requires_grad=False
# blocks.10.norm2.weight: requires_grad=False
# blocks.10.norm2.bias: requires_grad=False
# blocks.10.mlp.fc1.weight: requires_grad=False
# blocks.10.mlp.fc1.bias: requires_grad=False
# blocks.10.mlp.fc2.weight: requires_grad=False
# blocks.10.mlp.fc2.bias: requires_grad=False
# blocks.11.gamma_1: requires_grad=False
# blocks.11.gamma_2: requires_grad=False
# blocks.11.norm1.weight: requires_grad=False
# blocks.11.norm1.bias: requires_grad=False
# blocks.11.attn.qkv.weight: requires_grad=False
# blocks.11.attn.qkv.bias: requires_grad=False
# blocks.11.attn.proj.weight: requires_grad=False
# blocks.11.attn.proj.bias: requires_grad=False
# blocks.11.attn.proj_l.weight: requires_grad=False
# blocks.11.attn.proj_l.bias: requires_grad=False
# blocks.11.attn.proj_w.weight: requires_grad=False
# blocks.11.attn.proj_w.bias: requires_grad=False
# blocks.11.norm2.weight: requires_grad=False
# blocks.11.norm2.bias: requires_grad=False
# blocks.11.mlp.fc1.weight: requires_grad=False
# blocks.11.mlp.fc1.bias: requires_grad=False
# blocks.11.mlp.fc2.weight: requires_grad=False
# blocks.11.mlp.fc2.bias: requires_grad=False
# blocks.12.gamma_1: requires_grad=False
# blocks.12.gamma_2: requires_grad=False
# blocks.12.norm1.weight: requires_grad=False
# blocks.12.norm1.bias: requires_grad=False
# blocks.12.attn.qkv.weight: requires_grad=False
# blocks.12.attn.qkv.bias: requires_grad=False
# blocks.12.attn.proj.weight: requires_grad=False
# blocks.12.attn.proj.bias: requires_grad=False
# blocks.12.attn.proj_l.weight: requires_grad=False
# blocks.12.attn.proj_l.bias: requires_grad=False
# blocks.12.attn.proj_w.weight: requires_grad=False
# blocks.12.attn.proj_w.bias: requires_grad=False
# blocks.12.norm2.weight: requires_grad=False
# blocks.12.norm2.bias: requires_grad=False
# blocks.12.mlp.fc1.weight: requires_grad=False
# blocks.12.mlp.fc1.bias: requires_grad=False
# blocks.12.mlp.fc2.weight: requires_grad=False
# blocks.12.mlp.fc2.bias: requires_grad=False
# blocks.13.gamma_1: requires_grad=False
# blocks.13.gamma_2: requires_grad=False
# blocks.13.norm1.weight: requires_grad=False
# blocks.13.norm1.bias: requires_grad=False
# blocks.13.attn.qkv.weight: requires_grad=False
# blocks.13.attn.qkv.bias: requires_grad=False
# blocks.13.attn.proj.weight: requires_grad=False
# blocks.13.attn.proj.bias: requires_grad=False
# blocks.13.attn.proj_l.weight: requires_grad=False
# blocks.13.attn.proj_l.bias: requires_grad=False
# blocks.13.attn.proj_w.weight: requires_grad=False
# blocks.13.attn.proj_w.bias: requires_grad=False
# blocks.13.norm2.weight: requires_grad=False
# blocks.13.norm2.bias: requires_grad=False
# blocks.13.mlp.fc1.weight: requires_grad=False
# blocks.13.mlp.fc1.bias: requires_grad=False
# blocks.13.mlp.fc2.weight: requires_grad=False
# blocks.13.mlp.fc2.bias: requires_grad=False
# blocks.14.gamma_1: requires_grad=False
# blocks.14.gamma_2: requires_grad=False
# blocks.14.norm1.weight: requires_grad=False
# blocks.14.norm1.bias: requires_grad=False
# blocks.14.attn.qkv.weight: requires_grad=False
# blocks.14.attn.qkv.bias: requires_grad=False
# blocks.14.attn.proj.weight: requires_grad=False
# blocks.14.attn.proj.bias: requires_grad=False
# blocks.14.attn.proj_l.weight: requires_grad=False
# blocks.14.attn.proj_l.bias: requires_grad=False
# blocks.14.attn.proj_w.weight: requires_grad=False
# blocks.14.attn.proj_w.bias: requires_grad=False
# blocks.14.norm2.weight: requires_grad=False
# blocks.14.norm2.bias: requires_grad=False
# blocks.14.mlp.fc1.weight: requires_grad=False
# blocks.14.mlp.fc1.bias: requires_grad=False
# blocks.14.mlp.fc2.weight: requires_grad=False
# blocks.14.mlp.fc2.bias: requires_grad=False
# blocks.15.gamma_1: requires_grad=False
# blocks.15.gamma_2: requires_grad=False
# blocks.15.norm1.weight: requires_grad=False
# blocks.15.norm1.bias: requires_grad=False
# blocks.15.attn.qkv.weight: requires_grad=False
# blocks.15.attn.qkv.bias: requires_grad=False
# blocks.15.attn.proj.weight: requires_grad=False
# blocks.15.attn.proj.bias: requires_grad=False
# blocks.15.attn.proj_l.weight: requires_grad=False
# blocks.15.attn.proj_l.bias: requires_grad=False
# blocks.15.attn.proj_w.weight: requires_grad=False
# blocks.15.attn.proj_w.bias: requires_grad=False
# blocks.15.norm2.weight: requires_grad=False
# blocks.15.norm2.bias: requires_grad=False
# blocks.15.mlp.fc1.weight: requires_grad=False
# blocks.15.mlp.fc1.bias: requires_grad=False
# blocks.15.mlp.fc2.weight: requires_grad=False
# blocks.15.mlp.fc2.bias: requires_grad=False
# blocks.16.gamma_1: requires_grad=False
# blocks.16.gamma_2: requires_grad=False
# blocks.16.norm1.weight: requires_grad=False
# blocks.16.norm1.bias: requires_grad=False
# blocks.16.attn.qkv.weight: requires_grad=False
# blocks.16.attn.qkv.bias: requires_grad=False
# blocks.16.attn.proj.weight: requires_grad=False
# blocks.16.attn.proj.bias: requires_grad=False
# blocks.16.attn.proj_l.weight: requires_grad=False
# blocks.16.attn.proj_l.bias: requires_grad=False
# blocks.16.attn.proj_w.weight: requires_grad=False
# blocks.16.attn.proj_w.bias: requires_grad=False
# blocks.16.norm2.weight: requires_grad=False
# blocks.16.norm2.bias: requires_grad=False
# blocks.16.mlp.fc1.weight: requires_grad=False
# blocks.16.mlp.fc1.bias: requires_grad=False
# blocks.16.mlp.fc2.weight: requires_grad=False
# blocks.16.mlp.fc2.bias: requires_grad=False
# blocks.17.gamma_1: requires_grad=False
# blocks.17.gamma_2: requires_grad=False
# blocks.17.norm1.weight: requires_grad=False
# blocks.17.norm1.bias: requires_grad=False
# blocks.17.attn.qkv.weight: requires_grad=False
# blocks.17.attn.qkv.bias: requires_grad=False
# blocks.17.attn.proj.weight: requires_grad=False
# blocks.17.attn.proj.bias: requires_grad=False
# blocks.17.attn.proj_l.weight: requires_grad=False
# blocks.17.attn.proj_l.bias: requires_grad=False
# blocks.17.attn.proj_w.weight: requires_grad=False
# blocks.17.attn.proj_w.bias: requires_grad=False
# blocks.17.norm2.weight: requires_grad=False
# blocks.17.norm2.bias: requires_grad=False
# blocks.17.mlp.fc1.weight: requires_grad=False
# blocks.17.mlp.fc1.bias: requires_grad=False
# blocks.17.mlp.fc2.weight: requires_grad=False
# blocks.17.mlp.fc2.bias: requires_grad=False
# blocks.18.gamma_1: requires_grad=False
# blocks.18.gamma_2: requires_grad=False
# blocks.18.norm1.weight: requires_grad=False
# blocks.18.norm1.bias: requires_grad=False
# blocks.18.attn.qkv.weight: requires_grad=False
# blocks.18.attn.qkv.bias: requires_grad=False
# blocks.18.attn.proj.weight: requires_grad=False
# blocks.18.attn.proj.bias: requires_grad=False
# blocks.18.attn.proj_l.weight: requires_grad=False
# blocks.18.attn.proj_l.bias: requires_grad=False
# blocks.18.attn.proj_w.weight: requires_grad=False
# blocks.18.attn.proj_w.bias: requires_grad=False
# blocks.18.norm2.weight: requires_grad=False
# blocks.18.norm2.bias: requires_grad=False
# blocks.18.mlp.fc1.weight: requires_grad=False
# blocks.18.mlp.fc1.bias: requires_grad=False
# blocks.18.mlp.fc2.weight: requires_grad=False
# blocks.18.mlp.fc2.bias: requires_grad=False
# blocks.19.gamma_1: requires_grad=False
# blocks.19.gamma_2: requires_grad=False
# blocks.19.norm1.weight: requires_grad=False
# blocks.19.norm1.bias: requires_grad=False
# blocks.19.attn.qkv.weight: requires_grad=False
# blocks.19.attn.qkv.bias: requires_grad=False
# blocks.19.attn.proj.weight: requires_grad=False
# blocks.19.attn.proj.bias: requires_grad=False
# blocks.19.attn.proj_l.weight: requires_grad=False
# blocks.19.attn.proj_l.bias: requires_grad=False
# blocks.19.attn.proj_w.weight: requires_grad=False
# blocks.19.attn.proj_w.bias: requires_grad=False
# blocks.19.norm2.weight: requires_grad=False
# blocks.19.norm2.bias: requires_grad=False
# blocks.19.mlp.fc1.weight: requires_grad=False
# blocks.19.mlp.fc1.bias: requires_grad=False
# blocks.19.mlp.fc2.weight: requires_grad=False
# blocks.19.mlp.fc2.bias: requires_grad=False
# blocks.20.gamma_1: requires_grad=False
# blocks.20.gamma_2: requires_grad=False
# blocks.20.norm1.weight: requires_grad=False
# blocks.20.norm1.bias: requires_grad=False
# blocks.20.attn.qkv.weight: requires_grad=False
# blocks.20.attn.qkv.bias: requires_grad=False
# blocks.20.attn.proj.weight: requires_grad=False
# blocks.20.attn.proj.bias: requires_grad=False
# blocks.20.attn.proj_l.weight: requires_grad=False
# blocks.20.attn.proj_l.bias: requires_grad=False
# blocks.20.attn.proj_w.weight: requires_grad=False
# blocks.20.attn.proj_w.bias: requires_grad=False
# blocks.20.norm2.weight: requires_grad=False
# blocks.20.norm2.bias: requires_grad=False
# blocks.20.mlp.fc1.weight: requires_grad=False
# blocks.20.mlp.fc1.bias: requires_grad=False
# blocks.20.mlp.fc2.weight: requires_grad=False
# blocks.20.mlp.fc2.bias: requires_grad=False
# blocks.21.gamma_1: requires_grad=False
# blocks.21.gamma_2: requires_grad=False
# blocks.21.norm1.weight: requires_grad=False
# blocks.21.norm1.bias: requires_grad=False
# blocks.21.attn.qkv.weight: requires_grad=False
# blocks.21.attn.qkv.bias: requires_grad=False
# blocks.21.attn.proj.weight: requires_grad=False
# blocks.21.attn.proj.bias: requires_grad=False
# blocks.21.attn.proj_l.weight: requires_grad=False
# blocks.21.attn.proj_l.bias: requires_grad=False
# blocks.21.attn.proj_w.weight: requires_grad=False
# blocks.21.attn.proj_w.bias: requires_grad=False
# blocks.21.norm2.weight: requires_grad=False
# blocks.21.norm2.bias: requires_grad=False
# blocks.21.mlp.fc1.weight: requires_grad=False
# blocks.21.mlp.fc1.bias: requires_grad=False
# blocks.21.mlp.fc2.weight: requires_grad=False
# blocks.21.mlp.fc2.bias: requires_grad=False
# blocks.22.gamma_1: requires_grad=False
# blocks.22.gamma_2: requires_grad=False
# blocks.22.norm1.weight: requires_grad=False
# blocks.22.norm1.bias: requires_grad=False
# blocks.22.attn.qkv.weight: requires_grad=False
# blocks.22.attn.qkv.bias: requires_grad=False
# blocks.22.attn.proj.weight: requires_grad=False
# blocks.22.attn.proj.bias: requires_grad=False
# blocks.22.attn.proj_l.weight: requires_grad=False
# blocks.22.attn.proj_l.bias: requires_grad=False
# blocks.22.attn.proj_w.weight: requires_grad=False
# blocks.22.attn.proj_w.bias: requires_grad=False
# blocks.22.norm2.weight: requires_grad=False
# blocks.22.norm2.bias: requires_grad=False
# blocks.22.mlp.fc1.weight: requires_grad=False
# blocks.22.mlp.fc1.bias: requires_grad=False
# blocks.22.mlp.fc2.weight: requires_grad=False
# blocks.22.mlp.fc2.bias: requires_grad=False
# blocks.23.gamma_1: requires_grad=True
# blocks.23.gamma_2: requires_grad=True
# blocks.23.norm1.weight: requires_grad=True
# blocks.23.norm1.bias: requires_grad=True
# blocks.23.attn.qkv.weight: requires_grad=True
# blocks.23.attn.qkv.bias: requires_grad=True
# blocks.23.attn.proj.weight: requires_grad=True
# blocks.23.attn.proj.bias: requires_grad=True
# blocks.23.attn.proj_l.weight: requires_grad=True
# blocks.23.attn.proj_l.bias: requires_grad=True
# blocks.23.attn.proj_w.weight: requires_grad=True
# blocks.23.attn.proj_w.bias: requires_grad=True
# blocks.23.norm2.weight: requires_grad=True
# blocks.23.norm2.bias: requires_grad=True
# blocks.23.mlp.fc1.weight: requires_grad=True
# blocks.23.mlp.fc1.bias: requires_grad=True
# blocks.23.mlp.fc2.weight: requires_grad=True
# blocks.23.mlp.fc2.bias: requires_grad=True
# blocks_token_only.0.gamma_1: requires_grad=False
# blocks_token_only.0.gamma_2: requires_grad=False
# blocks_token_only.0.norm1.weight: requires_grad=False
# blocks_token_only.0.norm1.bias: requires_grad=False
# blocks_token_only.0.attn.q.weight: requires_grad=False
# blocks_token_only.0.attn.q.bias: requires_grad=False
# blocks_token_only.0.attn.k.weight: requires_grad=False
# blocks_token_only.0.attn.k.bias: requires_grad=False
# blocks_token_only.0.attn.v.weight: requires_grad=False
# blocks_token_only.0.attn.v.bias: requires_grad=False
# blocks_token_only.0.attn.proj.weight: requires_grad=False
# blocks_token_only.0.attn.proj.bias: requires_grad=False
# blocks_token_only.0.norm2.weight: requires_grad=False
# blocks_token_only.0.norm2.bias: requires_grad=False
# blocks_token_only.0.mlp.fc1.weight: requires_grad=False
# blocks_token_only.0.mlp.fc1.bias: requires_grad=False
# blocks_token_only.0.mlp.fc2.weight: requires_grad=False
# blocks_token_only.0.mlp.fc2.bias: requires_grad=False
# blocks_token_only.1.gamma_1: requires_grad=False
# blocks_token_only.1.gamma_2: requires_grad=False
# blocks_token_only.1.norm1.weight: requires_grad=False
# blocks_token_only.1.norm1.bias: requires_grad=False
# blocks_token_only.1.attn.q.weight: requires_grad=False
# blocks_token_only.1.attn.q.bias: requires_grad=False
# blocks_token_only.1.attn.k.weight: requires_grad=False
# blocks_token_only.1.attn.k.bias: requires_grad=False
# blocks_token_only.1.attn.v.weight: requires_grad=False
# blocks_token_only.1.attn.v.bias: requires_grad=False
# blocks_token_only.1.attn.proj.weight: requires_grad=False
# blocks_token_only.1.attn.proj.bias: requires_grad=False
# blocks_token_only.1.norm2.weight: requires_grad=False
# blocks_token_only.1.norm2.bias: requires_grad=False
# blocks_token_only.1.mlp.fc1.weight: requires_grad=False
# blocks_token_only.1.mlp.fc1.bias: requires_grad=False
# blocks_token_only.1.mlp.fc2.weight: requires_grad=False
# blocks_token_only.1.mlp.fc2.bias: requires_grad=False
# norm.weight: requires_grad=False
# norm.bias: requires_grad=False
# head.weight: requires_grad=True
# head.bias: requires_grad=True
# classifier.0.weight: requires_grad=True
# classifier.0.bias: requires_grad=True
# classifier.3.weight: requires_grad=True
# classifier.3.bias: requires_grad=True

# %%
if device.type == 'cuda':
    print(torch.cuda.get_device_name(0))
model.to(device)
# Out:
# Tesla T4
# Cait(
#   (patch_embed): PatchEmbed(
#     (proj): Conv2d(3, 384, kernel_size=(16, 16), stride=(16, 16))
#     (norm): Identity()
#   )
#   (pos_drop): Dropout(p=0.0, inplace=False)
#   (blocks): Sequential(
#     (0): LayerScaleBlock(
#       (norm1): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#       (attn): TalkingHeadAttn(
#         (qkv): Linear(in_features=384, out_features=1152, bias=True)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=384, out_features=384, bias=True)
#         (proj_l): Linear(in_features=8, out_features=8, bias=True)
#         (proj_w): Linear(in_features=8, out_features=8, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (drop_path): Identity()
#       (norm2): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=384, out_features=1536, bias=True)
#         (act): GELU(approximate='none')
#         (drop1): Dropout(p=0.0, inplace=False)
#         (norm): Identity()
#         (fc2): Linear(in_features=1536, out_features=384, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#     )
#     (1): LayerScaleBlock(
#       (norm1): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#       (attn): TalkingHeadAttn(
#         (qkv): Linear(in_features=384, out_features=1152, bias=True)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=384, out_features=384, bias=True)
#         (proj_l): Linear(in_features=8, out_features=8, bias=True)
#         (proj_w): Linear(in_features=8, out_features=8, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (drop_path): Identity()
#       (norm2): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=384, out_features=1536, bias=True)
#         (act): GELU(approximate='none')
#         (drop1): Dropout(p=0.0, inplace=False)
#         (norm): Identity()
#         (fc2): Linear(in_features=1536, out_features=384, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#     )
#     (2): LayerScaleBlock(
#       (norm1): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#       (attn): TalkingHeadAttn(
#         (qkv): Linear(in_features=384, out_features=1152, bias=True)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=384, out_features=384, bias=True)
#         (proj_l): Linear(in_features=8, out_features=8, bias=True)
#         (proj_w): Linear(in_features=8, out_features=8, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (drop_path): Identity()
#       (norm2): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=384, out_features=1536, bias=True)
#         (act): GELU(approximate='none')
#         (drop1): Dropout(p=0.0, inplace=False)
#         (norm): Identity()
#         (fc2): Linear(in_features=1536, out_features=384, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#     )
#     (3): LayerScaleBlock(
#       (norm1): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#       (attn): TalkingHeadAttn(
#         (qkv): Linear(in_features=384, out_features=1152, bias=True)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=384, out_features=384, bias=True)
#         (proj_l): Linear(in_features=8, out_features=8, bias=True)
#         (proj_w): Linear(in_features=8, out_features=8, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (drop_path): Identity()
#       (norm2): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=384, out_features=1536, bias=True)
#         (act): GELU(approximate='none')
#         (drop1): Dropout(p=0.0, inplace=False)
#         (norm): Identity()
#         (fc2): Linear(in_features=1536, out_features=384, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#     )
#     (4): LayerScaleBlock(
#       (norm1): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#       (attn): TalkingHeadAttn(
#         (qkv): Linear(in_features=384, out_features=1152, bias=True)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=384, out_features=384, bias=True)
#         (proj_l): Linear(in_features=8, out_features=8, bias=True)
#         (proj_w): Linear(in_features=8, out_features=8, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (drop_path): Identity()
#       (norm2): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=384, out_features=1536, bias=True)
#         (act): GELU(approximate='none')
#         (drop1): Dropout(p=0.0, inplace=False)
#         (norm): Identity()
#         (fc2): Linear(in_features=1536, out_features=384, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#     )
#     (5): LayerScaleBlock(
#       (norm1): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#       (attn): TalkingHeadAttn(
#         (qkv): Linear(in_features=384, out_features=1152, bias=True)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=384, out_features=384, bias=True)
#         (proj_l): Linear(in_features=8, out_features=8, bias=True)
#         (proj_w): Linear(in_features=8, out_features=8, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (drop_path): Identity()
#       (norm2): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=384, out_features=1536, bias=True)
#         (act): GELU(approximate='none')
#         (drop1): Dropout(p=0.0, inplace=False)
#         (norm): Identity()
#         (fc2): Linear(in_features=1536, out_features=384, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#     )
#     (6): LayerScaleBlock(
#       (norm1): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#       (attn): TalkingHeadAttn(
#         (qkv): Linear(in_features=384, out_features=1152, bias=True)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=384, out_features=384, bias=True)
#         (proj_l): Linear(in_features=8, out_features=8, bias=True)
#         (proj_w): Linear(in_features=8, out_features=8, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (drop_path): Identity()
#       (norm2): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=384, out_features=1536, bias=True)
#         (act): GELU(approximate='none')
#         (drop1): Dropout(p=0.0, inplace=False)
#         (norm): Identity()
#         (fc2): Linear(in_features=1536, out_features=384, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#     )
#     (7): LayerScaleBlock(
#       (norm1): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#       (attn): TalkingHeadAttn(
#         (qkv): Linear(in_features=384, out_features=1152, bias=True)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=384, out_features=384, bias=True)
#         (proj_l): Linear(in_features=8, out_features=8, bias=True)
#         (proj_w): Linear(in_features=8, out_features=8, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (drop_path): Identity()
#       (norm2): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=384, out_features=1536, bias=True)
#         (act): GELU(approximate='none')
#         (drop1): Dropout(p=0.0, inplace=False)
#         (norm): Identity()
#         (fc2): Linear(in_features=1536, out_features=384, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#     )
#     (8): LayerScaleBlock(
#       (norm1): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#       (attn): TalkingHeadAttn(
#         (qkv): Linear(in_features=384, out_features=1152, bias=True)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=384, out_features=384, bias=True)
#         (proj_l): Linear(in_features=8, out_features=8, bias=True)
#         (proj_w): Linear(in_features=8, out_features=8, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (drop_path): Identity()
#       (norm2): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=384, out_features=1536, bias=True)
#         (act): GELU(approximate='none')
#         (drop1): Dropout(p=0.0, inplace=False)
#         (norm): Identity()
#         (fc2): Linear(in_features=1536, out_features=384, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#     )
#     (9): LayerScaleBlock(
#       (norm1): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#       (attn): TalkingHeadAttn(
#         (qkv): Linear(in_features=384, out_features=1152, bias=True)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=384, out_features=384, bias=True)
#         (proj_l): Linear(in_features=8, out_features=8, bias=True)
#         (proj_w): Linear(in_features=8, out_features=8, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (drop_path): Identity()
#       (norm2): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=384, out_features=1536, bias=True)
#         (act): GELU(approximate='none')
#         (drop1): Dropout(p=0.0, inplace=False)
#         (norm): Identity()
#         (fc2): Linear(in_features=1536, out_features=384, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#     )
#     (10): LayerScaleBlock(
#       (norm1): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#       (attn): TalkingHeadAttn(
#         (qkv): Linear(in_features=384, out_features=1152, bias=True)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=384, out_features=384, bias=True)
#         (proj_l): Linear(in_features=8, out_features=8, bias=True)
#         (proj_w): Linear(in_features=8, out_features=8, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (drop_path): Identity()
#       (norm2): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=384, out_features=1536, bias=True)
#         (act): GELU(approximate='none')
#         (drop1): Dropout(p=0.0, inplace=False)
#         (norm): Identity()
#         (fc2): Linear(in_features=1536, out_features=384, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#     )
#     (11): LayerScaleBlock(
#       (norm1): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#       (attn): TalkingHeadAttn(
#         (qkv): Linear(in_features=384, out_features=1152, bias=True)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=384, out_features=384, bias=True)
#         (proj_l): Linear(in_features=8, out_features=8, bias=True)
#         (proj_w): Linear(in_features=8, out_features=8, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (drop_path): Identity()
#       (norm2): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=384, out_features=1536, bias=True)
#         (act): GELU(approximate='none')
#         (drop1): Dropout(p=0.0, inplace=False)
#         (norm): Identity()
#         (fc2): Linear(in_features=1536, out_features=384, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#     )
#     (12): LayerScaleBlock(
#       (norm1): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#       (attn): TalkingHeadAttn(
#         (qkv): Linear(in_features=384, out_features=1152, bias=True)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=384, out_features=384, bias=True)
#         (proj_l): Linear(in_features=8, out_features=8, bias=True)
#         (proj_w): Linear(in_features=8, out_features=8, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (drop_path): Identity()
#       (norm2): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=384, out_features=1536, bias=True)
#         (act): GELU(approximate='none')
#         (drop1): Dropout(p=0.0, inplace=False)
#         (norm): Identity()
#         (fc2): Linear(in_features=1536, out_features=384, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#     )
#     (13): LayerScaleBlock(
#       (norm1): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#       (attn): TalkingHeadAttn(
#         (qkv): Linear(in_features=384, out_features=1152, bias=True)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=384, out_features=384, bias=True)
#         (proj_l): Linear(in_features=8, out_features=8, bias=True)
#         (proj_w): Linear(in_features=8, out_features=8, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (drop_path): Identity()
#       (norm2): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=384, out_features=1536, bias=True)
#         (act): GELU(approximate='none')
#         (drop1): Dropout(p=0.0, inplace=False)
#         (norm): Identity()
#         (fc2): Linear(in_features=1536, out_features=384, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#     )
#     (14): LayerScaleBlock(
#       (norm1): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#       (attn): TalkingHeadAttn(
#         (qkv): Linear(in_features=384, out_features=1152, bias=True)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=384, out_features=384, bias=True)
#         (proj_l): Linear(in_features=8, out_features=8, bias=True)
#         (proj_w): Linear(in_features=8, out_features=8, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (drop_path): Identity()
#       (norm2): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=384, out_features=1536, bias=True)
#         (act): GELU(approximate='none')
#         (drop1): Dropout(p=0.0, inplace=False)
#         (norm): Identity()
#         (fc2): Linear(in_features=1536, out_features=384, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#     )
#     (15): LayerScaleBlock(
#       (norm1): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#       (attn): TalkingHeadAttn(
#         (qkv): Linear(in_features=384, out_features=1152, bias=True)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=384, out_features=384, bias=True)
#         (proj_l): Linear(in_features=8, out_features=8, bias=True)
#         (proj_w): Linear(in_features=8, out_features=8, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (drop_path): Identity()
#       (norm2): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=384, out_features=1536, bias=True)
#         (act): GELU(approximate='none')
#         (drop1): Dropout(p=0.0, inplace=False)
#         (norm): Identity()
#         (fc2): Linear(in_features=1536, out_features=384, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#     )
#     (16): LayerScaleBlock(
#       (norm1): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#       (attn): TalkingHeadAttn(
#         (qkv): Linear(in_features=384, out_features=1152, bias=True)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=384, out_features=384, bias=True)
#         (proj_l): Linear(in_features=8, out_features=8, bias=True)
#         (proj_w): Linear(in_features=8, out_features=8, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (drop_path): Identity()
#       (norm2): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=384, out_features=1536, bias=True)
#         (act): GELU(approximate='none')
#         (drop1): Dropout(p=0.0, inplace=False)
#         (norm): Identity()
#         (fc2): Linear(in_features=1536, out_features=384, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#     )
#     (17): LayerScaleBlock(
#       (norm1): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#       (attn): TalkingHeadAttn(
#         (qkv): Linear(in_features=384, out_features=1152, bias=True)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=384, out_features=384, bias=True)
#         (proj_l): Linear(in_features=8, out_features=8, bias=True)
#         (proj_w): Linear(in_features=8, out_features=8, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (drop_path): Identity()
#       (norm2): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=384, out_features=1536, bias=True)
#         (act): GELU(approximate='none')
#         (drop1): Dropout(p=0.0, inplace=False)
#         (norm): Identity()
#         (fc2): Linear(in_features=1536, out_features=384, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#     )
#     (18): LayerScaleBlock(
#       (norm1): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#       (attn): TalkingHeadAttn(
#         (qkv): Linear(in_features=384, out_features=1152, bias=True)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=384, out_features=384, bias=True)
#         (proj_l): Linear(in_features=8, out_features=8, bias=True)
#         (proj_w): Linear(in_features=8, out_features=8, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (drop_path): Identity()
#       (norm2): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=384, out_features=1536, bias=True)
#         (act): GELU(approximate='none')
#         (drop1): Dropout(p=0.0, inplace=False)
#         (norm): Identity()
#         (fc2): Linear(in_features=1536, out_features=384, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#     )
#     (19): LayerScaleBlock(
#       (norm1): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#       (attn): TalkingHeadAttn(
#         (qkv): Linear(in_features=384, out_features=1152, bias=True)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=384, out_features=384, bias=True)
#         (proj_l): Linear(in_features=8, out_features=8, bias=True)
#         (proj_w): Linear(in_features=8, out_features=8, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (drop_path): Identity()
#       (norm2): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=384, out_features=1536, bias=True)
#         (act): GELU(approximate='none')
#         (drop1): Dropout(p=0.0, inplace=False)
#         (norm): Identity()
#         (fc2): Linear(in_features=1536, out_features=384, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#     )
#     (20): LayerScaleBlock(
#       (norm1): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#       (attn): TalkingHeadAttn(
#         (qkv): Linear(in_features=384, out_features=1152, bias=True)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=384, out_features=384, bias=True)
#         (proj_l): Linear(in_features=8, out_features=8, bias=True)
#         (proj_w): Linear(in_features=8, out_features=8, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (drop_path): Identity()
#       (norm2): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=384, out_features=1536, bias=True)
#         (act): GELU(approximate='none')
#         (drop1): Dropout(p=0.0, inplace=False)
#         (norm): Identity()
#         (fc2): Linear(in_features=1536, out_features=384, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#     )
#     (21): LayerScaleBlock(
#       (norm1): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#       (attn): TalkingHeadAttn(
#         (qkv): Linear(in_features=384, out_features=1152, bias=True)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=384, out_features=384, bias=True)
#         (proj_l): Linear(in_features=8, out_features=8, bias=True)
#         (proj_w): Linear(in_features=8, out_features=8, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (drop_path): Identity()
#       (norm2): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=384, out_features=1536, bias=True)
#         (act): GELU(approximate='none')
#         (drop1): Dropout(p=0.0, inplace=False)
#         (norm): Identity()
#         (fc2): Linear(in_features=1536, out_features=384, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#     )
#     (22): LayerScaleBlock(
#       (norm1): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#       (attn): TalkingHeadAttn(
#         (qkv): Linear(in_features=384, out_features=1152, bias=True)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=384, out_features=384, bias=True)
#         (proj_l): Linear(in_features=8, out_features=8, bias=True)
#         (proj_w): Linear(in_features=8, out_features=8, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (drop_path): Identity()
#       (norm2): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=384, out_features=1536, bias=True)
#         (act): GELU(approximate='none')
#         (drop1): Dropout(p=0.0, inplace=False)
#         (norm): Identity()
#         (fc2): Linear(in_features=1536, out_features=384, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#     )
#     (23): LayerScaleBlock(
#       (norm1): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#       (attn): TalkingHeadAttn(
#         (qkv): Linear(in_features=384, out_features=1152, bias=True)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=384, out_features=384, bias=True)
#         (proj_l): Linear(in_features=8, out_features=8, bias=True)
#         (proj_w): Linear(in_features=8, out_features=8, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (drop_path): Identity()
#       (norm2): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=384, out_features=1536, bias=True)
#         (act): GELU(approximate='none')
#         (drop1): Dropout(p=0.0, inplace=False)
#         (norm): Identity()
#         (fc2): Linear(in_features=1536, out_features=384, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#     )
#   )
#   (blocks_token_only): ModuleList(
#     (0-1): 2 x LayerScaleBlockClassAttn(
#       (norm1): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#       (attn): ClassAttn(
#         (q): Linear(in_features=384, out_features=384, bias=True)
#         (k): Linear(in_features=384, out_features=384, bias=True)
#         (v): Linear(in_features=384, out_features=384, bias=True)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=384, out_features=384, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (drop_path): Identity()
#       (norm2): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=384, out_features=1536, bias=True)
#         (act): GELU(approximate='none')
#         (drop1): Dropout(p=0.0, inplace=False)
#         (norm): Identity()
#         (fc2): Linear(in_features=1536, out_features=384, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#     )
#   )
#   (norm): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#   (head_drop): Dropout(p=0.0, inplace=False)
#   (head): Linear(in_features=384, out_features=10, bias=True)
#   (classifier): Sequential(
#     (0): Linear(in_features=384, out_features=256, bias=True)
#     (1): ELU(alpha=1.0)
#     (2): Dropout(p=0.5, inplace=False)
#     (3): Linear(in_features=256, out_features=10, bias=True)
#   )
# )

# %%
num_epochs = 10
train_losses = []
val_losses = []
train_accuracies = []
val_accuracies = []
train_times = []
val_times = []
best_model_path = 'best_model.pth'
best_val_accuracy = 0.0

for epoch in range(num_epochs):
    start_time = time.time()
    model.train()
    running_loss = 0.0
    correct_train = 0
    total_train = 0
    for inputs, labels in trainloader:
        inputs, labels = inputs.to(device), labels.to(device)

        optimizer.zero_grad()

        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item()
        _, predicted = torch.max(outputs, 1)
        total_train += labels.size(0)
        correct_train += (predicted == labels).sum().item()

    train_losses.append(running_loss / len(trainloader))
    train_accuracies.append(100 * correct_train / total_train)

    epoch_time = time.time() - start_time
    train_times.append(epoch_time)

    model.eval()
    running_val_loss = 0.0
    correct_val = 0
    total_val = 0
    val_start_time = time.time()
    with torch.no_grad():
        for inputs, labels in testloader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            running_val_loss += loss.item()
            _, predicted = torch.max(outputs, 1)
            total_val += labels.size(0)
            correct_val += (predicted == labels).sum().item()

    val_epoch_time = time.time() - val_start_time
    val_times.append(val_epoch_time)

    val_losses.append(running_val_loss / len(testloader))
    val_accuracies.append(100 * correct_val / total_val)
    scheduler.step(val_accuracies[-1])
    
    if val_accuracies[-1] > best_val_accuracy:
        best_val_accuracy = val_accuracies[-1]
        torch.save(model.state_dict(), best_model_path)
    
    
    
    print(f'Epoch {epoch+1}/{num_epochs}, '
          f'Loss: {train_losses[-1]:.4f}, '
          f'Val Loss: {val_losses[-1]:.4f}, '
          f'Accuracy: {train_accuracies[-1]:.2f}%, '
          f'Val Accuracy: {val_accuracies[-1]:.2f}%, '
          f'Train Time: {epoch_time:.2f}s, '
          f'Val Time: {val_epoch_time:.2f}s')

    
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(train_losses, label='Train Loss')
plt.plot(val_losses, label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Loss vs Epochs')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(train_accuracies, label='Train Accuracy')
plt.plot(val_accuracies, label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy (%)')
plt.title('Accuracy vs Epochs')
plt.legend()

plt.show()

avg_train_time = sum(train_times) / num_epochs
avg_val_time = sum(val_times) / num_epochs
print(f'Average Training Time per Epoch: {avg_train_time:.2f}s')
print(f'Average Validation Time per Epoch: {avg_val_time:.2f}s')
# Out:
# Epoch 1/10, Loss: 0.1355, Val Loss: 0.1133, Accuracy: 95.58%, Val Accuracy: 96.08%, Train Time: 597.52s, Val Time: 109.22s
# Epoch 2/10, Loss: 0.0558, Val Loss: 0.0985, Accuracy: 98.14%, Val Accuracy: 96.77%, Train Time: 599.11s, Val Time: 109.58s
# Epoch 3/10, Loss: 0.0243, Val Loss: 0.1140, Accuracy: 99.20%, Val Accuracy: 96.67%, Train Time: 600.42s, Val Time: 109.68s
# Epoch 4/10, Loss: 0.0158, Val Loss: 0.1161, Accuracy: 99.50%, Val Accuracy: 96.80%, Train Time: 600.29s, Val Time: 109.69s
# Epoch 5/10, Loss: 0.0118, Val Loss: 0.1206, Accuracy: 99.61%, Val Accuracy: 96.94%, Train Time: 599.92s, Val Time: 109.53s
# Epoch 6/10, Loss: 0.0090, Val Loss: 0.1602, Accuracy: 99.68%, Val Accuracy: 96.36%, Train Time: 600.20s, Val Time: 109.68s
# Epoch 7/10, Loss: 0.0079, Val Loss: 0.1509, Accuracy: 99.72%, Val Accuracy: 96.79%, Train Time: 600.14s, Val Time: 109.34s
# Epoch 8/10, Loss: 0.0073, Val Loss: 0.1571, Accuracy: 99.76%, Val Accuracy: 96.78%, Train Time: 600.10s, Val Time: 109.62s
# Epoch 00009: reducing learning rate of group 0 to 6.0000e-05.
# Epoch 9/10, Loss: 0.0073, Val Loss: 0.1788, Accuracy: 99.77%, Val Accuracy: 96.36%, Train Time: 599.80s, Val Time: 109.58s
# Epoch 10/10, Loss: 0.0034, Val Loss: 0.1436, Accuracy: 99.90%, Val Accuracy: 97.04%, Train Time: 599.30s, Val Time: 109.67s
# Average Training Time per Epoch: 599.68s
# Average Validation Time per Epoch: 109.56s

# %%
import torch
import torchvision
import matplotlib.pyplot as plt
import numpy as np


def imshow(img):
    img = img / 2 + 0.5  
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()

dataiter = iter(trainloader)
images, labels = next(dataiter)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
images = images.to(device)

model.eval()
outputs = model(images)
_, predicted = torch.max(outputs, 1)

images = images.cpu()
predicted = predicted.cpu()

fig, axes = plt.subplots(2, 4, figsize=(12, 6))
fig.subplots_adjust(hspace=0.3)
axes = axes.ravel()

for i in range(8):
    image = images[i] / 2 + 0.5  
    npimg = image.numpy()
    axes[i].imshow(np.transpose(npimg, (1, 2, 0)))
    axes[i].set_title(f'Predicted: {trainloader.dataset.classes[predicted[i]]}', color='green' if predicted[i] == labels[i] else 'red')
    axes[i].axis('off')

plt.show()

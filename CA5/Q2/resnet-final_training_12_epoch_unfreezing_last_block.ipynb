# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
from torchvision import models
import time
import matplotlib.pyplot as plt

transform_train = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize((0.485, 0.456, 0.406), (0.229, 0.224, 0.225)),  
])

transform_test = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize((0.485, 0.456, 0.406), (0.229, 0.224, 0.225)),  
])

trainset = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=transform_train)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=8, shuffle=True, num_workers=2)

testset = torchvision.datasets.CIFAR10(root='./data', train=False, download=True, transform=transform_test)
testloader = torch.utils.data.DataLoader(testset, batch_size=8, shuffle=False, num_workers=2)
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./data/cifar-10-python.tar.gz
# 100%|██████████| 170498071/170498071 [00:01<00:00, 103082265.10it/s]
# Extracting ./data/cifar-10-python.tar.gz to ./data
# Files already downloaded and verified

# %%
trainset
# Out:
# Dataset CIFAR10
#     Number of datapoints: 50000
#     Root location: ./data
#     Split: Train
#     StandardTransform
# Transform: Compose(
#                Resize(size=(224, 224), interpolation=bilinear, max_size=None, antialias=warn)
#                RandomHorizontalFlip(p=0.5)
#                ToTensor()
#                Normalize(mean=(0.485, 0.456, 0.406), std=(0.229, 0.224, 0.225))
#            )

# %%
testset
# Out:
# Dataset CIFAR10
#     Number of datapoints: 10000
#     Root location: ./data
#     Split: Test
#     StandardTransform
# Transform: Compose(
#                Resize(size=(224, 224), interpolation=bilinear, max_size=None, antialias=warn)
#                ToTensor()
#                Normalize(mean=(0.485, 0.456, 0.406), std=(0.229, 0.224, 0.225))
#            )

# %%
# !pip install torchsummary
# Out:
# Collecting torchsummary
#   Downloading torchsummary-1.5.1-py3-none-any.whl.metadata (296 bytes)
# Downloading torchsummary-1.5.1-py3-none-any.whl (2.8 kB)
# Installing collected packages: torchsummary
# Successfully installed torchsummary-1.5.1

# %%
import torch
import torch.nn as nn
import torchvision.models as models
from torch.optim.lr_scheduler import ReduceLROnPlateau
from torchsummary import summary
import warnings

warnings.filterwarnings("ignore")

model = models.resnet152(pretrained=True)

for param in model.parameters():
    param.requires_grad = False

for name, param in model.named_parameters():
    if 'layer4' in name or 'bn1' in name or 'bn2' in name or 'bn3' in name:
        param.requires_grad = True

num_ftrs = model.fc.in_features
model.fc = nn.Sequential(
    nn.Linear(num_ftrs, 256),
    nn.ReLU(True),
    nn.Dropout(0.5),
    nn.Linear(256, 10),  
)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)

summary(model, (3, 224, 224))

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.0001)
scheduler = ReduceLROnPlateau(optimizer, mode='max', factor=0.6, patience=3, verbose=True, min_lr=1e-7)



print("\nLayer status:")
for name, param in model.named_parameters():
    print(f"{name}: requires_grad={param.requires_grad}")
# Out:
# Downloading: "https://download.pytorch.org/models/resnet152-394f9c45.pth" to /root/.cache/torch/hub/checkpoints/resnet152-394f9c45.pth
# 100%|██████████| 230M/230M [00:01<00:00, 155MB/s]
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 64, 112, 112]           9,408
#        BatchNorm2d-2         [-1, 64, 112, 112]             128
#               ReLU-3         [-1, 64, 112, 112]               0
#          MaxPool2d-4           [-1, 64, 56, 56]               0
#             Conv2d-5           [-1, 64, 56, 56]           4,096
#        BatchNorm2d-6           [-1, 64, 56, 56]             128
#               ReLU-7           [-1, 64, 56, 56]               0
#             Conv2d-8           [-1, 64, 56, 56]          36,864
#        BatchNorm2d-9           [-1, 64, 56, 56]             128
#              ReLU-10           [-1, 64, 56, 56]               0
#            Conv2d-11          [-1, 256, 56, 56]          16,384
#       BatchNorm2d-12          [-1, 256, 56, 56]             512
#            Conv2d-13          [-1, 256, 56, 56]          16,384
#       BatchNorm2d-14          [-1, 256, 56, 56]             512
#              ReLU-15          [-1, 256, 56, 56]               0
#        Bottleneck-16          [-1, 256, 56, 56]               0
#            Conv2d-17           [-1, 64, 56, 56]          16,384
#       BatchNorm2d-18           [-1, 64, 56, 56]             128
#              ReLU-19           [-1, 64, 56, 56]               0
#            Conv2d-20           [-1, 64, 56, 56]          36,864
#       BatchNorm2d-21           [-1, 64, 56, 56]             128
#              ReLU-22           [-1, 64, 56, 56]               0
#            Conv2d-23          [-1, 256, 56, 56]          16,384
#       BatchNorm2d-24          [-1, 256, 56, 56]             512
#              ReLU-25          [-1, 256, 56, 56]               0
#        Bottleneck-26          [-1, 256, 56, 56]               0
#            Conv2d-27           [-1, 64, 56, 56]          16,384
#       BatchNorm2d-28           [-1, 64, 56, 56]             128
#              ReLU-29           [-1, 64, 56, 56]               0
#            Conv2d-30           [-1, 64, 56, 56]          36,864
#       BatchNorm2d-31           [-1, 64, 56, 56]             128
#              ReLU-32           [-1, 64, 56, 56]               0
#            Conv2d-33          [-1, 256, 56, 56]          16,384
#       BatchNorm2d-34          [-1, 256, 56, 56]             512
#              ReLU-35          [-1, 256, 56, 56]               0
#        Bottleneck-36          [-1, 256, 56, 56]               0
#            Conv2d-37          [-1, 128, 56, 56]          32,768
#       BatchNorm2d-38          [-1, 128, 56, 56]             256
#              ReLU-39          [-1, 128, 56, 56]               0
#            Conv2d-40          [-1, 128, 28, 28]         147,456
#       BatchNorm2d-41          [-1, 128, 28, 28]             256
#              ReLU-42          [-1, 128, 28, 28]               0
#            Conv2d-43          [-1, 512, 28, 28]          65,536
#       BatchNorm2d-44          [-1, 512, 28, 28]           1,024
#            Conv2d-45          [-1, 512, 28, 28]         131,072
#       BatchNorm2d-46          [-1, 512, 28, 28]           1,024
#              ReLU-47          [-1, 512, 28, 28]               0
#        Bottleneck-48          [-1, 512, 28, 28]               0
#            Conv2d-49          [-1, 128, 28, 28]          65,536
#       BatchNorm2d-50          [-1, 128, 28, 28]             256
#              ReLU-51          [-1, 128, 28, 28]               0
#            Conv2d-52          [-1, 128, 28, 28]         147,456
#       BatchNorm2d-53          [-1, 128, 28, 28]             256
#              ReLU-54          [-1, 128, 28, 28]               0
#            Conv2d-55          [-1, 512, 28, 28]          65,536
#       BatchNorm2d-56          [-1, 512, 28, 28]           1,024
#              ReLU-57          [-1, 512, 28, 28]               0
#        Bottleneck-58          [-1, 512, 28, 28]               0
#            Conv2d-59          [-1, 128, 28, 28]          65,536
#       BatchNorm2d-60          [-1, 128, 28, 28]             256
#              ReLU-61          [-1, 128, 28, 28]               0
#            Conv2d-62          [-1, 128, 28, 28]         147,456
#       BatchNorm2d-63          [-1, 128, 28, 28]             256
#              ReLU-64          [-1, 128, 28, 28]               0
#            Conv2d-65          [-1, 512, 28, 28]          65,536
#       BatchNorm2d-66          [-1, 512, 28, 28]           1,024
#              ReLU-67          [-1, 512, 28, 28]               0
#        Bottleneck-68          [-1, 512, 28, 28]               0
#            Conv2d-69          [-1, 128, 28, 28]          65,536
#       BatchNorm2d-70          [-1, 128, 28, 28]             256
#              ReLU-71          [-1, 128, 28, 28]               0
#            Conv2d-72          [-1, 128, 28, 28]         147,456
#       BatchNorm2d-73          [-1, 128, 28, 28]             256
#              ReLU-74          [-1, 128, 28, 28]               0
#            Conv2d-75          [-1, 512, 28, 28]          65,536
#       BatchNorm2d-76          [-1, 512, 28, 28]           1,024
#              ReLU-77          [-1, 512, 28, 28]               0
#        Bottleneck-78          [-1, 512, 28, 28]               0
#            Conv2d-79          [-1, 128, 28, 28]          65,536
#       BatchNorm2d-80          [-1, 128, 28, 28]             256
#              ReLU-81          [-1, 128, 28, 28]               0
#            Conv2d-82          [-1, 128, 28, 28]         147,456
#       BatchNorm2d-83          [-1, 128, 28, 28]             256
#              ReLU-84          [-1, 128, 28, 28]               0
#            Conv2d-85          [-1, 512, 28, 28]          65,536
#       BatchNorm2d-86          [-1, 512, 28, 28]           1,024
#              ReLU-87          [-1, 512, 28, 28]               0
#        Bottleneck-88          [-1, 512, 28, 28]               0
#            Conv2d-89          [-1, 128, 28, 28]          65,536
#       BatchNorm2d-90          [-1, 128, 28, 28]             256
#              ReLU-91          [-1, 128, 28, 28]               0
#            Conv2d-92          [-1, 128, 28, 28]         147,456
#       BatchNorm2d-93          [-1, 128, 28, 28]             256
#              ReLU-94          [-1, 128, 28, 28]               0
#            Conv2d-95          [-1, 512, 28, 28]          65,536
#       BatchNorm2d-96          [-1, 512, 28, 28]           1,024
#              ReLU-97          [-1, 512, 28, 28]               0
#        Bottleneck-98          [-1, 512, 28, 28]               0
#            Conv2d-99          [-1, 128, 28, 28]          65,536
#      BatchNorm2d-100          [-1, 128, 28, 28]             256
#             ReLU-101          [-1, 128, 28, 28]               0
#           Conv2d-102          [-1, 128, 28, 28]         147,456
#      BatchNorm2d-103          [-1, 128, 28, 28]             256
#             ReLU-104          [-1, 128, 28, 28]               0
#           Conv2d-105          [-1, 512, 28, 28]          65,536
#      BatchNorm2d-106          [-1, 512, 28, 28]           1,024
#             ReLU-107          [-1, 512, 28, 28]               0
#       Bottleneck-108          [-1, 512, 28, 28]               0
#           Conv2d-109          [-1, 128, 28, 28]          65,536
#      BatchNorm2d-110          [-1, 128, 28, 28]             256
#             ReLU-111          [-1, 128, 28, 28]               0
#           Conv2d-112          [-1, 128, 28, 28]         147,456
#      BatchNorm2d-113          [-1, 128, 28, 28]             256
#             ReLU-114          [-1, 128, 28, 28]               0
#           Conv2d-115          [-1, 512, 28, 28]          65,536
#      BatchNorm2d-116          [-1, 512, 28, 28]           1,024
#             ReLU-117          [-1, 512, 28, 28]               0
#       Bottleneck-118          [-1, 512, 28, 28]               0
#           Conv2d-119          [-1, 256, 28, 28]         131,072
#      BatchNorm2d-120          [-1, 256, 28, 28]             512
#             ReLU-121          [-1, 256, 28, 28]               0
#           Conv2d-122          [-1, 256, 14, 14]         589,824
#      BatchNorm2d-123          [-1, 256, 14, 14]             512
#             ReLU-124          [-1, 256, 14, 14]               0
#           Conv2d-125         [-1, 1024, 14, 14]         262,144
#      BatchNorm2d-126         [-1, 1024, 14, 14]           2,048
#           Conv2d-127         [-1, 1024, 14, 14]         524,288
#      BatchNorm2d-128         [-1, 1024, 14, 14]           2,048
#             ReLU-129         [-1, 1024, 14, 14]               0
#       Bottleneck-130         [-1, 1024, 14, 14]               0
#           Conv2d-131          [-1, 256, 14, 14]         262,144
#      BatchNorm2d-132          [-1, 256, 14, 14]             512
#             ReLU-133          [-1, 256, 14, 14]               0
#           Conv2d-134          [-1, 256, 14, 14]         589,824
#      BatchNorm2d-135          [-1, 256, 14, 14]             512
#             ReLU-136          [-1, 256, 14, 14]               0
#           Conv2d-137         [-1, 1024, 14, 14]         262,144
#      BatchNorm2d-138         [-1, 1024, 14, 14]           2,048
#             ReLU-139         [-1, 1024, 14, 14]               0
#       Bottleneck-140         [-1, 1024, 14, 14]               0
#           Conv2d-141          [-1, 256, 14, 14]         262,144
#      BatchNorm2d-142          [-1, 256, 14, 14]             512
#             ReLU-143          [-1, 256, 14, 14]               0
#           Conv2d-144          [-1, 256, 14, 14]         589,824
#      BatchNorm2d-145          [-1, 256, 14, 14]             512
#             ReLU-146          [-1, 256, 14, 14]               0
#           Conv2d-147         [-1, 1024, 14, 14]         262,144
#      BatchNorm2d-148         [-1, 1024, 14, 14]           2,048
#             ReLU-149         [-1, 1024, 14, 14]               0
#       Bottleneck-150         [-1, 1024, 14, 14]               0
#           Conv2d-151          [-1, 256, 14, 14]         262,144
#      BatchNorm2d-152          [-1, 256, 14, 14]             512
#             ReLU-153          [-1, 256, 14, 14]               0
#           Conv2d-154          [-1, 256, 14, 14]         589,824
#      BatchNorm2d-155          [-1, 256, 14, 14]             512
#             ReLU-156          [-1, 256, 14, 14]               0
#           Conv2d-157         [-1, 1024, 14, 14]         262,144
#      BatchNorm2d-158         [-1, 1024, 14, 14]           2,048
#             ReLU-159         [-1, 1024, 14, 14]               0
#       Bottleneck-160         [-1, 1024, 14, 14]               0
#           Conv2d-161          [-1, 256, 14, 14]         262,144
#      BatchNorm2d-162          [-1, 256, 14, 14]             512
#             ReLU-163          [-1, 256, 14, 14]               0
#           Conv2d-164          [-1, 256, 14, 14]         589,824
#      BatchNorm2d-165          [-1, 256, 14, 14]             512
#             ReLU-166          [-1, 256, 14, 14]               0
#           Conv2d-167         [-1, 1024, 14, 14]         262,144
#      BatchNorm2d-168         [-1, 1024, 14, 14]           2,048
#             ReLU-169         [-1, 1024, 14, 14]               0
#       Bottleneck-170         [-1, 1024, 14, 14]               0
#           Conv2d-171          [-1, 256, 14, 14]         262,144
#      BatchNorm2d-172          [-1, 256, 14, 14]             512
#             ReLU-173          [-1, 256, 14, 14]               0
#           Conv2d-174          [-1, 256, 14, 14]         589,824
#      BatchNorm2d-175          [-1, 256, 14, 14]             512
#             ReLU-176          [-1, 256, 14, 14]               0
#           Conv2d-177         [-1, 1024, 14, 14]         262,144
#      BatchNorm2d-178         [-1, 1024, 14, 14]           2,048
#             ReLU-179         [-1, 1024, 14, 14]               0
#       Bottleneck-180         [-1, 1024, 14, 14]               0
#           Conv2d-181          [-1, 256, 14, 14]         262,144
#      BatchNorm2d-182          [-1, 256, 14, 14]             512
#             ReLU-183          [-1, 256, 14, 14]               0
#           Conv2d-184          [-1, 256, 14, 14]         589,824
#      BatchNorm2d-185          [-1, 256, 14, 14]             512
#             ReLU-186          [-1, 256, 14, 14]               0
#           Conv2d-187         [-1, 1024, 14, 14]         262,144
#      BatchNorm2d-188         [-1, 1024, 14, 14]           2,048
#             ReLU-189         [-1, 1024, 14, 14]               0
#       Bottleneck-190         [-1, 1024, 14, 14]               0
#           Conv2d-191          [-1, 256, 14, 14]         262,144
#      BatchNorm2d-192          [-1, 256, 14, 14]             512
#             ReLU-193          [-1, 256, 14, 14]               0
#           Conv2d-194          [-1, 256, 14, 14]         589,824
#      BatchNorm2d-195          [-1, 256, 14, 14]             512
#             ReLU-196          [-1, 256, 14, 14]               0
#           Conv2d-197         [-1, 1024, 14, 14]         262,144
#      BatchNorm2d-198         [-1, 1024, 14, 14]           2,048
#             ReLU-199         [-1, 1024, 14, 14]               0
#       Bottleneck-200         [-1, 1024, 14, 14]               0
#           Conv2d-201          [-1, 256, 14, 14]         262,144
#      BatchNorm2d-202          [-1, 256, 14, 14]             512
#             ReLU-203          [-1, 256, 14, 14]               0
#           Conv2d-204          [-1, 256, 14, 14]         589,824
#      BatchNorm2d-205          [-1, 256, 14, 14]             512
#             ReLU-206          [-1, 256, 14, 14]               0
#           Conv2d-207         [-1, 1024, 14, 14]         262,144
#      BatchNorm2d-208         [-1, 1024, 14, 14]           2,048
#             ReLU-209         [-1, 1024, 14, 14]               0
#       Bottleneck-210         [-1, 1024, 14, 14]               0
#           Conv2d-211          [-1, 256, 14, 14]         262,144
#      BatchNorm2d-212          [-1, 256, 14, 14]             512
#             ReLU-213          [-1, 256, 14, 14]               0
#           Conv2d-214          [-1, 256, 14, 14]         589,824
#      BatchNorm2d-215          [-1, 256, 14, 14]             512
#             ReLU-216          [-1, 256, 14, 14]               0
#           Conv2d-217         [-1, 1024, 14, 14]         262,144
#      BatchNorm2d-218         [-1, 1024, 14, 14]           2,048
#             ReLU-219         [-1, 1024, 14, 14]               0
#       Bottleneck-220         [-1, 1024, 14, 14]               0
#           Conv2d-221          [-1, 256, 14, 14]         262,144
#      BatchNorm2d-222          [-1, 256, 14, 14]             512
#             ReLU-223          [-1, 256, 14, 14]               0
#           Conv2d-224          [-1, 256, 14, 14]         589,824
#      BatchNorm2d-225          [-1, 256, 14, 14]             512
#             ReLU-226          [-1, 256, 14, 14]               0
#           Conv2d-227         [-1, 1024, 14, 14]         262,144
#      BatchNorm2d-228         [-1, 1024, 14, 14]           2,048
#             ReLU-229         [-1, 1024, 14, 14]               0
#       Bottleneck-230         [-1, 1024, 14, 14]               0
#           Conv2d-231          [-1, 256, 14, 14]         262,144
#      BatchNorm2d-232          [-1, 256, 14, 14]             512
#             ReLU-233          [-1, 256, 14, 14]               0
#           Conv2d-234          [-1, 256, 14, 14]         589,824
#      BatchNorm2d-235          [-1, 256, 14, 14]             512
#             ReLU-236          [-1, 256, 14, 14]               0
#           Conv2d-237         [-1, 1024, 14, 14]         262,144
#      BatchNorm2d-238         [-1, 1024, 14, 14]           2,048
#             ReLU-239         [-1, 1024, 14, 14]               0
#       Bottleneck-240         [-1, 1024, 14, 14]               0
#           Conv2d-241          [-1, 256, 14, 14]         262,144
#      BatchNorm2d-242          [-1, 256, 14, 14]             512
#             ReLU-243          [-1, 256, 14, 14]               0
#           Conv2d-244          [-1, 256, 14, 14]         589,824
#      BatchNorm2d-245          [-1, 256, 14, 14]             512
#             ReLU-246          [-1, 256, 14, 14]               0
#           Conv2d-247         [-1, 1024, 14, 14]         262,144
#      BatchNorm2d-248         [-1, 1024, 14, 14]           2,048
#             ReLU-249         [-1, 1024, 14, 14]               0
#       Bottleneck-250         [-1, 1024, 14, 14]               0
#           Conv2d-251          [-1, 256, 14, 14]         262,144
#      BatchNorm2d-252          [-1, 256, 14, 14]             512
#             ReLU-253          [-1, 256, 14, 14]               0
#           Conv2d-254          [-1, 256, 14, 14]         589,824
#      BatchNorm2d-255          [-1, 256, 14, 14]             512
#             ReLU-256          [-1, 256, 14, 14]               0
#           Conv2d-257         [-1, 1024, 14, 14]         262,144
#      BatchNorm2d-258         [-1, 1024, 14, 14]           2,048
#             ReLU-259         [-1, 1024, 14, 14]               0
#       Bottleneck-260         [-1, 1024, 14, 14]               0
#           Conv2d-261          [-1, 256, 14, 14]         262,144
#      BatchNorm2d-262          [-1, 256, 14, 14]             512
#             ReLU-263          [-1, 256, 14, 14]               0
#           Conv2d-264          [-1, 256, 14, 14]         589,824
#      BatchNorm2d-265          [-1, 256, 14, 14]             512
#             ReLU-266          [-1, 256, 14, 14]               0
#           Conv2d-267         [-1, 1024, 14, 14]         262,144
#      BatchNorm2d-268         [-1, 1024, 14, 14]           2,048
#             ReLU-269         [-1, 1024, 14, 14]               0
#       Bottleneck-270         [-1, 1024, 14, 14]               0
#           Conv2d-271          [-1, 256, 14, 14]         262,144
#      BatchNorm2d-272          [-1, 256, 14, 14]             512
#             ReLU-273          [-1, 256, 14, 14]               0
#           Conv2d-274          [-1, 256, 14, 14]         589,824
#      BatchNorm2d-275          [-1, 256, 14, 14]             512
#             ReLU-276          [-1, 256, 14, 14]               0
#           Conv2d-277         [-1, 1024, 14, 14]         262,144
#      BatchNorm2d-278         [-1, 1024, 14, 14]           2,048
#             ReLU-279         [-1, 1024, 14, 14]               0
#       Bottleneck-280         [-1, 1024, 14, 14]               0
#           Conv2d-281          [-1, 256, 14, 14]         262,144
#      BatchNorm2d-282          [-1, 256, 14, 14]             512
#             ReLU-283          [-1, 256, 14, 14]               0
#           Conv2d-284          [-1, 256, 14, 14]         589,824
#      BatchNorm2d-285          [-1, 256, 14, 14]             512
#             ReLU-286          [-1, 256, 14, 14]               0
#           Conv2d-287         [-1, 1024, 14, 14]         262,144
#      BatchNorm2d-288         [-1, 1024, 14, 14]           2,048
#             ReLU-289         [-1, 1024, 14, 14]               0
#       Bottleneck-290         [-1, 1024, 14, 14]               0
#           Conv2d-291          [-1, 256, 14, 14]         262,144
#      BatchNorm2d-292          [-1, 256, 14, 14]             512
#             ReLU-293          [-1, 256, 14, 14]               0
#           Conv2d-294          [-1, 256, 14, 14]         589,824
#      BatchNorm2d-295          [-1, 256, 14, 14]             512
#             ReLU-296          [-1, 256, 14, 14]               0
#           Conv2d-297         [-1, 1024, 14, 14]         262,144
#      BatchNorm2d-298         [-1, 1024, 14, 14]           2,048
#             ReLU-299         [-1, 1024, 14, 14]               0
#       Bottleneck-300         [-1, 1024, 14, 14]               0
#           Conv2d-301          [-1, 256, 14, 14]         262,144
#      BatchNorm2d-302          [-1, 256, 14, 14]             512
#             ReLU-303          [-1, 256, 14, 14]               0
#           Conv2d-304          [-1, 256, 14, 14]         589,824
#      BatchNorm2d-305          [-1, 256, 14, 14]             512
#             ReLU-306          [-1, 256, 14, 14]               0
#           Conv2d-307         [-1, 1024, 14, 14]         262,144
#      BatchNorm2d-308         [-1, 1024, 14, 14]           2,048
#             ReLU-309         [-1, 1024, 14, 14]               0
#       Bottleneck-310         [-1, 1024, 14, 14]               0
#           Conv2d-311          [-1, 256, 14, 14]         262,144
#      BatchNorm2d-312          [-1, 256, 14, 14]             512
#             ReLU-313          [-1, 256, 14, 14]               0
#           Conv2d-314          [-1, 256, 14, 14]         589,824
#      BatchNorm2d-315          [-1, 256, 14, 14]             512
#             ReLU-316          [-1, 256, 14, 14]               0
#           Conv2d-317         [-1, 1024, 14, 14]         262,144
#      BatchNorm2d-318         [-1, 1024, 14, 14]           2,048
#             ReLU-319         [-1, 1024, 14, 14]               0
#       Bottleneck-320         [-1, 1024, 14, 14]               0
#           Conv2d-321          [-1, 256, 14, 14]         262,144
#      BatchNorm2d-322          [-1, 256, 14, 14]             512
#             ReLU-323          [-1, 256, 14, 14]               0
#           Conv2d-324          [-1, 256, 14, 14]         589,824
#      BatchNorm2d-325          [-1, 256, 14, 14]             512
#             ReLU-326          [-1, 256, 14, 14]               0
#           Conv2d-327         [-1, 1024, 14, 14]         262,144
#      BatchNorm2d-328         [-1, 1024, 14, 14]           2,048
#             ReLU-329         [-1, 1024, 14, 14]               0
#       Bottleneck-330         [-1, 1024, 14, 14]               0
#           Conv2d-331          [-1, 256, 14, 14]         262,144
#      BatchNorm2d-332          [-1, 256, 14, 14]             512
#             ReLU-333          [-1, 256, 14, 14]               0
#           Conv2d-334          [-1, 256, 14, 14]         589,824
#      BatchNorm2d-335          [-1, 256, 14, 14]             512
#             ReLU-336          [-1, 256, 14, 14]               0
#           Conv2d-337         [-1, 1024, 14, 14]         262,144
#      BatchNorm2d-338         [-1, 1024, 14, 14]           2,048
#             ReLU-339         [-1, 1024, 14, 14]               0
#       Bottleneck-340         [-1, 1024, 14, 14]               0
#           Conv2d-341          [-1, 256, 14, 14]         262,144
#      BatchNorm2d-342          [-1, 256, 14, 14]             512
#             ReLU-343          [-1, 256, 14, 14]               0
#           Conv2d-344          [-1, 256, 14, 14]         589,824
#      BatchNorm2d-345          [-1, 256, 14, 14]             512
#             ReLU-346          [-1, 256, 14, 14]               0
#           Conv2d-347         [-1, 1024, 14, 14]         262,144
#      BatchNorm2d-348         [-1, 1024, 14, 14]           2,048
#             ReLU-349         [-1, 1024, 14, 14]               0
#       Bottleneck-350         [-1, 1024, 14, 14]               0
#           Conv2d-351          [-1, 256, 14, 14]         262,144
#      BatchNorm2d-352          [-1, 256, 14, 14]             512
#             ReLU-353          [-1, 256, 14, 14]               0
#           Conv2d-354          [-1, 256, 14, 14]         589,824
#      BatchNorm2d-355          [-1, 256, 14, 14]             512
#             ReLU-356          [-1, 256, 14, 14]               0
#           Conv2d-357         [-1, 1024, 14, 14]         262,144
#      BatchNorm2d-358         [-1, 1024, 14, 14]           2,048
#             ReLU-359         [-1, 1024, 14, 14]               0
#       Bottleneck-360         [-1, 1024, 14, 14]               0
#           Conv2d-361          [-1, 256, 14, 14]         262,144
#      BatchNorm2d-362          [-1, 256, 14, 14]             512
#             ReLU-363          [-1, 256, 14, 14]               0
#           Conv2d-364          [-1, 256, 14, 14]         589,824
#      BatchNorm2d-365          [-1, 256, 14, 14]             512
#             ReLU-366          [-1, 256, 14, 14]               0
#           Conv2d-367         [-1, 1024, 14, 14]         262,144
#      BatchNorm2d-368         [-1, 1024, 14, 14]           2,048
#             ReLU-369         [-1, 1024, 14, 14]               0
#       Bottleneck-370         [-1, 1024, 14, 14]               0
#           Conv2d-371          [-1, 256, 14, 14]         262,144
#      BatchNorm2d-372          [-1, 256, 14, 14]             512
#             ReLU-373          [-1, 256, 14, 14]               0
#           Conv2d-374          [-1, 256, 14, 14]         589,824
#      BatchNorm2d-375          [-1, 256, 14, 14]             512
#             ReLU-376          [-1, 256, 14, 14]               0
#           Conv2d-377         [-1, 1024, 14, 14]         262,144
#      BatchNorm2d-378         [-1, 1024, 14, 14]           2,048
#             ReLU-379         [-1, 1024, 14, 14]               0
#       Bottleneck-380         [-1, 1024, 14, 14]               0
#           Conv2d-381          [-1, 256, 14, 14]         262,144
#      BatchNorm2d-382          [-1, 256, 14, 14]             512
#             ReLU-383          [-1, 256, 14, 14]               0
#           Conv2d-384          [-1, 256, 14, 14]         589,824
#      BatchNorm2d-385          [-1, 256, 14, 14]             512
#             ReLU-386          [-1, 256, 14, 14]               0
#           Conv2d-387         [-1, 1024, 14, 14]         262,144
#      BatchNorm2d-388         [-1, 1024, 14, 14]           2,048
#             ReLU-389         [-1, 1024, 14, 14]               0
#       Bottleneck-390         [-1, 1024, 14, 14]               0
#           Conv2d-391          [-1, 256, 14, 14]         262,144
#      BatchNorm2d-392          [-1, 256, 14, 14]             512
#             ReLU-393          [-1, 256, 14, 14]               0
#           Conv2d-394          [-1, 256, 14, 14]         589,824
#      BatchNorm2d-395          [-1, 256, 14, 14]             512
#             ReLU-396          [-1, 256, 14, 14]               0
#           Conv2d-397         [-1, 1024, 14, 14]         262,144
#      BatchNorm2d-398         [-1, 1024, 14, 14]           2,048
#             ReLU-399         [-1, 1024, 14, 14]               0
#       Bottleneck-400         [-1, 1024, 14, 14]               0
#           Conv2d-401          [-1, 256, 14, 14]         262,144
#      BatchNorm2d-402          [-1, 256, 14, 14]             512
#             ReLU-403          [-1, 256, 14, 14]               0
#           Conv2d-404          [-1, 256, 14, 14]         589,824
#      BatchNorm2d-405          [-1, 256, 14, 14]             512
#             ReLU-406          [-1, 256, 14, 14]               0
#           Conv2d-407         [-1, 1024, 14, 14]         262,144
#      BatchNorm2d-408         [-1, 1024, 14, 14]           2,048
#             ReLU-409         [-1, 1024, 14, 14]               0
#       Bottleneck-410         [-1, 1024, 14, 14]               0
#           Conv2d-411          [-1, 256, 14, 14]         262,144
#      BatchNorm2d-412          [-1, 256, 14, 14]             512
#             ReLU-413          [-1, 256, 14, 14]               0
#           Conv2d-414          [-1, 256, 14, 14]         589,824
#      BatchNorm2d-415          [-1, 256, 14, 14]             512
#             ReLU-416          [-1, 256, 14, 14]               0
#           Conv2d-417         [-1, 1024, 14, 14]         262,144
#      BatchNorm2d-418         [-1, 1024, 14, 14]           2,048
#             ReLU-419         [-1, 1024, 14, 14]               0
#       Bottleneck-420         [-1, 1024, 14, 14]               0
#           Conv2d-421          [-1, 256, 14, 14]         262,144
#      BatchNorm2d-422          [-1, 256, 14, 14]             512
#             ReLU-423          [-1, 256, 14, 14]               0
#           Conv2d-424          [-1, 256, 14, 14]         589,824
#      BatchNorm2d-425          [-1, 256, 14, 14]             512
#             ReLU-426          [-1, 256, 14, 14]               0
#           Conv2d-427         [-1, 1024, 14, 14]         262,144
#      BatchNorm2d-428         [-1, 1024, 14, 14]           2,048
#             ReLU-429         [-1, 1024, 14, 14]               0
#       Bottleneck-430         [-1, 1024, 14, 14]               0
#           Conv2d-431          [-1, 256, 14, 14]         262,144
#      BatchNorm2d-432          [-1, 256, 14, 14]             512
#             ReLU-433          [-1, 256, 14, 14]               0
#           Conv2d-434          [-1, 256, 14, 14]         589,824
#      BatchNorm2d-435          [-1, 256, 14, 14]             512
#             ReLU-436          [-1, 256, 14, 14]               0
#           Conv2d-437         [-1, 1024, 14, 14]         262,144
#      BatchNorm2d-438         [-1, 1024, 14, 14]           2,048
#             ReLU-439         [-1, 1024, 14, 14]               0
#       Bottleneck-440         [-1, 1024, 14, 14]               0
#           Conv2d-441          [-1, 256, 14, 14]         262,144
#      BatchNorm2d-442          [-1, 256, 14, 14]             512
#             ReLU-443          [-1, 256, 14, 14]               0
#           Conv2d-444          [-1, 256, 14, 14]         589,824
#      BatchNorm2d-445          [-1, 256, 14, 14]             512
#             ReLU-446          [-1, 256, 14, 14]               0
#           Conv2d-447         [-1, 1024, 14, 14]         262,144
#      BatchNorm2d-448         [-1, 1024, 14, 14]           2,048
#             ReLU-449         [-1, 1024, 14, 14]               0
#       Bottleneck-450         [-1, 1024, 14, 14]               0
#           Conv2d-451          [-1, 256, 14, 14]         262,144
#      BatchNorm2d-452          [-1, 256, 14, 14]             512
#             ReLU-453          [-1, 256, 14, 14]               0
#           Conv2d-454          [-1, 256, 14, 14]         589,824
#      BatchNorm2d-455          [-1, 256, 14, 14]             512
#             ReLU-456          [-1, 256, 14, 14]               0
#           Conv2d-457         [-1, 1024, 14, 14]         262,144
#      BatchNorm2d-458         [-1, 1024, 14, 14]           2,048
#             ReLU-459         [-1, 1024, 14, 14]               0
#       Bottleneck-460         [-1, 1024, 14, 14]               0
#           Conv2d-461          [-1, 256, 14, 14]         262,144
#      BatchNorm2d-462          [-1, 256, 14, 14]             512
#             ReLU-463          [-1, 256, 14, 14]               0
#           Conv2d-464          [-1, 256, 14, 14]         589,824
#      BatchNorm2d-465          [-1, 256, 14, 14]             512
#             ReLU-466          [-1, 256, 14, 14]               0
#           Conv2d-467         [-1, 1024, 14, 14]         262,144
#      BatchNorm2d-468         [-1, 1024, 14, 14]           2,048
#             ReLU-469         [-1, 1024, 14, 14]               0
#       Bottleneck-470         [-1, 1024, 14, 14]               0
#           Conv2d-471          [-1, 256, 14, 14]         262,144
#      BatchNorm2d-472          [-1, 256, 14, 14]             512
#             ReLU-473          [-1, 256, 14, 14]               0
#           Conv2d-474          [-1, 256, 14, 14]         589,824
#      BatchNorm2d-475          [-1, 256, 14, 14]             512
#             ReLU-476          [-1, 256, 14, 14]               0
#           Conv2d-477         [-1, 1024, 14, 14]         262,144
#      BatchNorm2d-478         [-1, 1024, 14, 14]           2,048
#             ReLU-479         [-1, 1024, 14, 14]               0
#       Bottleneck-480         [-1, 1024, 14, 14]               0
#           Conv2d-481          [-1, 512, 14, 14]         524,288
#      BatchNorm2d-482          [-1, 512, 14, 14]           1,024
#             ReLU-483          [-1, 512, 14, 14]               0
#           Conv2d-484            [-1, 512, 7, 7]       2,359,296
#      BatchNorm2d-485            [-1, 512, 7, 7]           1,024
#             ReLU-486            [-1, 512, 7, 7]               0
#           Conv2d-487           [-1, 2048, 7, 7]       1,048,576
#      BatchNorm2d-488           [-1, 2048, 7, 7]           4,096
#           Conv2d-489           [-1, 2048, 7, 7]       2,097,152
#      BatchNorm2d-490           [-1, 2048, 7, 7]           4,096
#             ReLU-491           [-1, 2048, 7, 7]               0
#       Bottleneck-492           [-1, 2048, 7, 7]               0
#           Conv2d-493            [-1, 512, 7, 7]       1,048,576
#      BatchNorm2d-494            [-1, 512, 7, 7]           1,024
#             ReLU-495            [-1, 512, 7, 7]               0
#           Conv2d-496            [-1, 512, 7, 7]       2,359,296
#      BatchNorm2d-497            [-1, 512, 7, 7]           1,024
#             ReLU-498            [-1, 512, 7, 7]               0
#           Conv2d-499           [-1, 2048, 7, 7]       1,048,576
#      BatchNorm2d-500           [-1, 2048, 7, 7]           4,096
#             ReLU-501           [-1, 2048, 7, 7]               0
#       Bottleneck-502           [-1, 2048, 7, 7]               0
#           Conv2d-503            [-1, 512, 7, 7]       1,048,576
#      BatchNorm2d-504            [-1, 512, 7, 7]           1,024
#             ReLU-505            [-1, 512, 7, 7]               0
#           Conv2d-506            [-1, 512, 7, 7]       2,359,296
#      BatchNorm2d-507            [-1, 512, 7, 7]           1,024
#             ReLU-508            [-1, 512, 7, 7]               0
#           Conv2d-509           [-1, 2048, 7, 7]       1,048,576
#      BatchNorm2d-510           [-1, 2048, 7, 7]           4,096
#             ReLU-511           [-1, 2048, 7, 7]               0
#       Bottleneck-512           [-1, 2048, 7, 7]               0
# AdaptiveAvgPool2d-513           [-1, 2048, 1, 1]               0
#           Linear-514                  [-1, 256]         524,544
#             ReLU-515                  [-1, 256]               0
#          Dropout-516                  [-1, 256]               0
#           Linear-517                   [-1, 10]           2,570
# ================================================================
# Total params: 58,670,922
# Trainable params: 15,617,162
# Non-trainable params: 43,053,760
# ----------------------------------------------------------------
# Input size (MB): 0.57
# Forward/backward pass size (MB): 606.59
# Params size (MB): 223.81
# Estimated Total Size (MB): 830.97
# ----------------------------------------------------------------
#
# Layer status:
# conv1.weight: requires_grad=False
# bn1.weight: requires_grad=True
# bn1.bias: requires_grad=True
# layer1.0.conv1.weight: requires_grad=False
# layer1.0.bn1.weight: requires_grad=True
# layer1.0.bn1.bias: requires_grad=True
# layer1.0.conv2.weight: requires_grad=False
# layer1.0.bn2.weight: requires_grad=True
# layer1.0.bn2.bias: requires_grad=True
# layer1.0.conv3.weight: requires_grad=False
# layer1.0.bn3.weight: requires_grad=True
# layer1.0.bn3.bias: requires_grad=True
# layer1.0.downsample.0.weight: requires_grad=False
# layer1.0.downsample.1.weight: requires_grad=False
# layer1.0.downsample.1.bias: requires_grad=False
# layer1.1.conv1.weight: requires_grad=False
# layer1.1.bn1.weight: requires_grad=True
# layer1.1.bn1.bias: requires_grad=True
# layer1.1.conv2.weight: requires_grad=False
# layer1.1.bn2.weight: requires_grad=True
# layer1.1.bn2.bias: requires_grad=True
# layer1.1.conv3.weight: requires_grad=False
# layer1.1.bn3.weight: requires_grad=True
# layer1.1.bn3.bias: requires_grad=True
# layer1.2.conv1.weight: requires_grad=False
# layer1.2.bn1.weight: requires_grad=True
# layer1.2.bn1.bias: requires_grad=True
# layer1.2.conv2.weight: requires_grad=False
# layer1.2.bn2.weight: requires_grad=True
# layer1.2.bn2.bias: requires_grad=True
# layer1.2.conv3.weight: requires_grad=False
# layer1.2.bn3.weight: requires_grad=True
# layer1.2.bn3.bias: requires_grad=True
# layer2.0.conv1.weight: requires_grad=False
# layer2.0.bn1.weight: requires_grad=True
# layer2.0.bn1.bias: requires_grad=True
# layer2.0.conv2.weight: requires_grad=False
# layer2.0.bn2.weight: requires_grad=True
# layer2.0.bn2.bias: requires_grad=True
# layer2.0.conv3.weight: requires_grad=False
# layer2.0.bn3.weight: requires_grad=True
# layer2.0.bn3.bias: requires_grad=True
# layer2.0.downsample.0.weight: requires_grad=False
# layer2.0.downsample.1.weight: requires_grad=False
# layer2.0.downsample.1.bias: requires_grad=False
# layer2.1.conv1.weight: requires_grad=False
# layer2.1.bn1.weight: requires_grad=True
# layer2.1.bn1.bias: requires_grad=True
# layer2.1.conv2.weight: requires_grad=False
# layer2.1.bn2.weight: requires_grad=True
# layer2.1.bn2.bias: requires_grad=True
# layer2.1.conv3.weight: requires_grad=False
# layer2.1.bn3.weight: requires_grad=True
# layer2.1.bn3.bias: requires_grad=True
# layer2.2.conv1.weight: requires_grad=False
# layer2.2.bn1.weight: requires_grad=True
# layer2.2.bn1.bias: requires_grad=True
# layer2.2.conv2.weight: requires_grad=False
# layer2.2.bn2.weight: requires_grad=True
# layer2.2.bn2.bias: requires_grad=True
# layer2.2.conv3.weight: requires_grad=False
# layer2.2.bn3.weight: requires_grad=True
# layer2.2.bn3.bias: requires_grad=True
# layer2.3.conv1.weight: requires_grad=False
# layer2.3.bn1.weight: requires_grad=True
# layer2.3.bn1.bias: requires_grad=True
# layer2.3.conv2.weight: requires_grad=False
# layer2.3.bn2.weight: requires_grad=True
# layer2.3.bn2.bias: requires_grad=True
# layer2.3.conv3.weight: requires_grad=False
# layer2.3.bn3.weight: requires_grad=True
# layer2.3.bn3.bias: requires_grad=True
# layer2.4.conv1.weight: requires_grad=False
# layer2.4.bn1.weight: requires_grad=True
# layer2.4.bn1.bias: requires_grad=True
# layer2.4.conv2.weight: requires_grad=False
# layer2.4.bn2.weight: requires_grad=True
# layer2.4.bn2.bias: requires_grad=True
# layer2.4.conv3.weight: requires_grad=False
# layer2.4.bn3.weight: requires_grad=True
# layer2.4.bn3.bias: requires_grad=True
# layer2.5.conv1.weight: requires_grad=False
# layer2.5.bn1.weight: requires_grad=True
# layer2.5.bn1.bias: requires_grad=True
# layer2.5.conv2.weight: requires_grad=False
# layer2.5.bn2.weight: requires_grad=True
# layer2.5.bn2.bias: requires_grad=True
# layer2.5.conv3.weight: requires_grad=False
# layer2.5.bn3.weight: requires_grad=True
# layer2.5.bn3.bias: requires_grad=True
# layer2.6.conv1.weight: requires_grad=False
# layer2.6.bn1.weight: requires_grad=True
# layer2.6.bn1.bias: requires_grad=True
# layer2.6.conv2.weight: requires_grad=False
# layer2.6.bn2.weight: requires_grad=True
# layer2.6.bn2.bias: requires_grad=True
# layer2.6.conv3.weight: requires_grad=False
# layer2.6.bn3.weight: requires_grad=True
# layer2.6.bn3.bias: requires_grad=True
# layer2.7.conv1.weight: requires_grad=False
# layer2.7.bn1.weight: requires_grad=True
# layer2.7.bn1.bias: requires_grad=True
# layer2.7.conv2.weight: requires_grad=False
# layer2.7.bn2.weight: requires_grad=True
# layer2.7.bn2.bias: requires_grad=True
# layer2.7.conv3.weight: requires_grad=False
# layer2.7.bn3.weight: requires_grad=True
# layer2.7.bn3.bias: requires_grad=True
# layer3.0.conv1.weight: requires_grad=False
# layer3.0.bn1.weight: requires_grad=True
# layer3.0.bn1.bias: requires_grad=True
# layer3.0.conv2.weight: requires_grad=False
# layer3.0.bn2.weight: requires_grad=True
# layer3.0.bn2.bias: requires_grad=True
# layer3.0.conv3.weight: requires_grad=False
# layer3.0.bn3.weight: requires_grad=True
# layer3.0.bn3.bias: requires_grad=True
# layer3.0.downsample.0.weight: requires_grad=False
# layer3.0.downsample.1.weight: requires_grad=False
# layer3.0.downsample.1.bias: requires_grad=False
# layer3.1.conv1.weight: requires_grad=False
# layer3.1.bn1.weight: requires_grad=True
# layer3.1.bn1.bias: requires_grad=True
# layer3.1.conv2.weight: requires_grad=False
# layer3.1.bn2.weight: requires_grad=True
# layer3.1.bn2.bias: requires_grad=True
# layer3.1.conv3.weight: requires_grad=False
# layer3.1.bn3.weight: requires_grad=True
# layer3.1.bn3.bias: requires_grad=True
# layer3.2.conv1.weight: requires_grad=False
# layer3.2.bn1.weight: requires_grad=True
# layer3.2.bn1.bias: requires_grad=True
# layer3.2.conv2.weight: requires_grad=False
# layer3.2.bn2.weight: requires_grad=True
# layer3.2.bn2.bias: requires_grad=True
# layer3.2.conv3.weight: requires_grad=False
# layer3.2.bn3.weight: requires_grad=True
# layer3.2.bn3.bias: requires_grad=True
# layer3.3.conv1.weight: requires_grad=False
# layer3.3.bn1.weight: requires_grad=True
# layer3.3.bn1.bias: requires_grad=True
# layer3.3.conv2.weight: requires_grad=False
# layer3.3.bn2.weight: requires_grad=True
# layer3.3.bn2.bias: requires_grad=True
# layer3.3.conv3.weight: requires_grad=False
# layer3.3.bn3.weight: requires_grad=True
# layer3.3.bn3.bias: requires_grad=True
# layer3.4.conv1.weight: requires_grad=False
# layer3.4.bn1.weight: requires_grad=True
# layer3.4.bn1.bias: requires_grad=True
# layer3.4.conv2.weight: requires_grad=False
# layer3.4.bn2.weight: requires_grad=True
# layer3.4.bn2.bias: requires_grad=True
# layer3.4.conv3.weight: requires_grad=False
# layer3.4.bn3.weight: requires_grad=True
# layer3.4.bn3.bias: requires_grad=True
# layer3.5.conv1.weight: requires_grad=False
# layer3.5.bn1.weight: requires_grad=True
# layer3.5.bn1.bias: requires_grad=True
# layer3.5.conv2.weight: requires_grad=False
# layer3.5.bn2.weight: requires_grad=True
# layer3.5.bn2.bias: requires_grad=True
# layer3.5.conv3.weight: requires_grad=False
# layer3.5.bn3.weight: requires_grad=True
# layer3.5.bn3.bias: requires_grad=True
# layer3.6.conv1.weight: requires_grad=False
# layer3.6.bn1.weight: requires_grad=True
# layer3.6.bn1.bias: requires_grad=True
# layer3.6.conv2.weight: requires_grad=False
# layer3.6.bn2.weight: requires_grad=True
# layer3.6.bn2.bias: requires_grad=True
# layer3.6.conv3.weight: requires_grad=False
# layer3.6.bn3.weight: requires_grad=True
# layer3.6.bn3.bias: requires_grad=True
# layer3.7.conv1.weight: requires_grad=False
# layer3.7.bn1.weight: requires_grad=True
# layer3.7.bn1.bias: requires_grad=True
# layer3.7.conv2.weight: requires_grad=False
# layer3.7.bn2.weight: requires_grad=True
# layer3.7.bn2.bias: requires_grad=True
# layer3.7.conv3.weight: requires_grad=False
# layer3.7.bn3.weight: requires_grad=True
# layer3.7.bn3.bias: requires_grad=True
# layer3.8.conv1.weight: requires_grad=False
# layer3.8.bn1.weight: requires_grad=True
# layer3.8.bn1.bias: requires_grad=True
# layer3.8.conv2.weight: requires_grad=False
# layer3.8.bn2.weight: requires_grad=True
# layer3.8.bn2.bias: requires_grad=True
# layer3.8.conv3.weight: requires_grad=False
# layer3.8.bn3.weight: requires_grad=True
# layer3.8.bn3.bias: requires_grad=True
# layer3.9.conv1.weight: requires_grad=False
# layer3.9.bn1.weight: requires_grad=True
# layer3.9.bn1.bias: requires_grad=True
# layer3.9.conv2.weight: requires_grad=False
# layer3.9.bn2.weight: requires_grad=True
# layer3.9.bn2.bias: requires_grad=True
# layer3.9.conv3.weight: requires_grad=False
# layer3.9.bn3.weight: requires_grad=True
# layer3.9.bn3.bias: requires_grad=True
# layer3.10.conv1.weight: requires_grad=False
# layer3.10.bn1.weight: requires_grad=True
# layer3.10.bn1.bias: requires_grad=True
# layer3.10.conv2.weight: requires_grad=False
# layer3.10.bn2.weight: requires_grad=True
# layer3.10.bn2.bias: requires_grad=True
# layer3.10.conv3.weight: requires_grad=False
# layer3.10.bn3.weight: requires_grad=True
# layer3.10.bn3.bias: requires_grad=True
# layer3.11.conv1.weight: requires_grad=False
# layer3.11.bn1.weight: requires_grad=True
# layer3.11.bn1.bias: requires_grad=True
# layer3.11.conv2.weight: requires_grad=False
# layer3.11.bn2.weight: requires_grad=True
# layer3.11.bn2.bias: requires_grad=True
# layer3.11.conv3.weight: requires_grad=False
# layer3.11.bn3.weight: requires_grad=True
# layer3.11.bn3.bias: requires_grad=True
# layer3.12.conv1.weight: requires_grad=False
# layer3.12.bn1.weight: requires_grad=True
# layer3.12.bn1.bias: requires_grad=True
# layer3.12.conv2.weight: requires_grad=False
# layer3.12.bn2.weight: requires_grad=True
# layer3.12.bn2.bias: requires_grad=True
# layer3.12.conv3.weight: requires_grad=False
# layer3.12.bn3.weight: requires_grad=True
# layer3.12.bn3.bias: requires_grad=True
# layer3.13.conv1.weight: requires_grad=False
# layer3.13.bn1.weight: requires_grad=True
# layer3.13.bn1.bias: requires_grad=True
# layer3.13.conv2.weight: requires_grad=False
# layer3.13.bn2.weight: requires_grad=True
# layer3.13.bn2.bias: requires_grad=True
# layer3.13.conv3.weight: requires_grad=False
# layer3.13.bn3.weight: requires_grad=True
# layer3.13.bn3.bias: requires_grad=True
# layer3.14.conv1.weight: requires_grad=False
# layer3.14.bn1.weight: requires_grad=True
# layer3.14.bn1.bias: requires_grad=True
# layer3.14.conv2.weight: requires_grad=False
# layer3.14.bn2.weight: requires_grad=True
# layer3.14.bn2.bias: requires_grad=True
# layer3.14.conv3.weight: requires_grad=False
# layer3.14.bn3.weight: requires_grad=True
# layer3.14.bn3.bias: requires_grad=True
# layer3.15.conv1.weight: requires_grad=False
# layer3.15.bn1.weight: requires_grad=True
# layer3.15.bn1.bias: requires_grad=True
# layer3.15.conv2.weight: requires_grad=False
# layer3.15.bn2.weight: requires_grad=True
# layer3.15.bn2.bias: requires_grad=True
# layer3.15.conv3.weight: requires_grad=False
# layer3.15.bn3.weight: requires_grad=True
# layer3.15.bn3.bias: requires_grad=True
# layer3.16.conv1.weight: requires_grad=False
# layer3.16.bn1.weight: requires_grad=True
# layer3.16.bn1.bias: requires_grad=True
# layer3.16.conv2.weight: requires_grad=False
# layer3.16.bn2.weight: requires_grad=True
# layer3.16.bn2.bias: requires_grad=True
# layer3.16.conv3.weight: requires_grad=False
# layer3.16.bn3.weight: requires_grad=True
# layer3.16.bn3.bias: requires_grad=True
# layer3.17.conv1.weight: requires_grad=False
# layer3.17.bn1.weight: requires_grad=True
# layer3.17.bn1.bias: requires_grad=True
# layer3.17.conv2.weight: requires_grad=False
# layer3.17.bn2.weight: requires_grad=True
# layer3.17.bn2.bias: requires_grad=True
# layer3.17.conv3.weight: requires_grad=False
# layer3.17.bn3.weight: requires_grad=True
# layer3.17.bn3.bias: requires_grad=True
# layer3.18.conv1.weight: requires_grad=False
# layer3.18.bn1.weight: requires_grad=True
# layer3.18.bn1.bias: requires_grad=True
# layer3.18.conv2.weight: requires_grad=False
# layer3.18.bn2.weight: requires_grad=True
# layer3.18.bn2.bias: requires_grad=True
# layer3.18.conv3.weight: requires_grad=False
# layer3.18.bn3.weight: requires_grad=True
# layer3.18.bn3.bias: requires_grad=True
# layer3.19.conv1.weight: requires_grad=False
# layer3.19.bn1.weight: requires_grad=True
# layer3.19.bn1.bias: requires_grad=True
# layer3.19.conv2.weight: requires_grad=False
# layer3.19.bn2.weight: requires_grad=True
# layer3.19.bn2.bias: requires_grad=True
# layer3.19.conv3.weight: requires_grad=False
# layer3.19.bn3.weight: requires_grad=True
# layer3.19.bn3.bias: requires_grad=True
# layer3.20.conv1.weight: requires_grad=False
# layer3.20.bn1.weight: requires_grad=True
# layer3.20.bn1.bias: requires_grad=True
# layer3.20.conv2.weight: requires_grad=False
# layer3.20.bn2.weight: requires_grad=True
# layer3.20.bn2.bias: requires_grad=True
# layer3.20.conv3.weight: requires_grad=False
# layer3.20.bn3.weight: requires_grad=True
# layer3.20.bn3.bias: requires_grad=True
# layer3.21.conv1.weight: requires_grad=False
# layer3.21.bn1.weight: requires_grad=True
# layer3.21.bn1.bias: requires_grad=True
# layer3.21.conv2.weight: requires_grad=False
# layer3.21.bn2.weight: requires_grad=True
# layer3.21.bn2.bias: requires_grad=True
# layer3.21.conv3.weight: requires_grad=False
# layer3.21.bn3.weight: requires_grad=True
# layer3.21.bn3.bias: requires_grad=True
# layer3.22.conv1.weight: requires_grad=False
# layer3.22.bn1.weight: requires_grad=True
# layer3.22.bn1.bias: requires_grad=True
# layer3.22.conv2.weight: requires_grad=False
# layer3.22.bn2.weight: requires_grad=True
# layer3.22.bn2.bias: requires_grad=True
# layer3.22.conv3.weight: requires_grad=False
# layer3.22.bn3.weight: requires_grad=True
# layer3.22.bn3.bias: requires_grad=True
# layer3.23.conv1.weight: requires_grad=False
# layer3.23.bn1.weight: requires_grad=True
# layer3.23.bn1.bias: requires_grad=True
# layer3.23.conv2.weight: requires_grad=False
# layer3.23.bn2.weight: requires_grad=True
# layer3.23.bn2.bias: requires_grad=True
# layer3.23.conv3.weight: requires_grad=False
# layer3.23.bn3.weight: requires_grad=True
# layer3.23.bn3.bias: requires_grad=True
# layer3.24.conv1.weight: requires_grad=False
# layer3.24.bn1.weight: requires_grad=True
# layer3.24.bn1.bias: requires_grad=True
# layer3.24.conv2.weight: requires_grad=False
# layer3.24.bn2.weight: requires_grad=True
# layer3.24.bn2.bias: requires_grad=True
# layer3.24.conv3.weight: requires_grad=False
# layer3.24.bn3.weight: requires_grad=True
# layer3.24.bn3.bias: requires_grad=True
# layer3.25.conv1.weight: requires_grad=False
# layer3.25.bn1.weight: requires_grad=True
# layer3.25.bn1.bias: requires_grad=True
# layer3.25.conv2.weight: requires_grad=False
# layer3.25.bn2.weight: requires_grad=True
# layer3.25.bn2.bias: requires_grad=True
# layer3.25.conv3.weight: requires_grad=False
# layer3.25.bn3.weight: requires_grad=True
# layer3.25.bn3.bias: requires_grad=True
# layer3.26.conv1.weight: requires_grad=False
# layer3.26.bn1.weight: requires_grad=True
# layer3.26.bn1.bias: requires_grad=True
# layer3.26.conv2.weight: requires_grad=False
# layer3.26.bn2.weight: requires_grad=True
# layer3.26.bn2.bias: requires_grad=True
# layer3.26.conv3.weight: requires_grad=False
# layer3.26.bn3.weight: requires_grad=True
# layer3.26.bn3.bias: requires_grad=True
# layer3.27.conv1.weight: requires_grad=False
# layer3.27.bn1.weight: requires_grad=True
# layer3.27.bn1.bias: requires_grad=True
# layer3.27.conv2.weight: requires_grad=False
# layer3.27.bn2.weight: requires_grad=True
# layer3.27.bn2.bias: requires_grad=True
# layer3.27.conv3.weight: requires_grad=False
# layer3.27.bn3.weight: requires_grad=True
# layer3.27.bn3.bias: requires_grad=True
# layer3.28.conv1.weight: requires_grad=False
# layer3.28.bn1.weight: requires_grad=True
# layer3.28.bn1.bias: requires_grad=True
# layer3.28.conv2.weight: requires_grad=False
# layer3.28.bn2.weight: requires_grad=True
# layer3.28.bn2.bias: requires_grad=True
# layer3.28.conv3.weight: requires_grad=False
# layer3.28.bn3.weight: requires_grad=True
# layer3.28.bn3.bias: requires_grad=True
# layer3.29.conv1.weight: requires_grad=False
# layer3.29.bn1.weight: requires_grad=True
# layer3.29.bn1.bias: requires_grad=True
# layer3.29.conv2.weight: requires_grad=False
# layer3.29.bn2.weight: requires_grad=True
# layer3.29.bn2.bias: requires_grad=True
# layer3.29.conv3.weight: requires_grad=False
# layer3.29.bn3.weight: requires_grad=True
# layer3.29.bn3.bias: requires_grad=True
# layer3.30.conv1.weight: requires_grad=False
# layer3.30.bn1.weight: requires_grad=True
# layer3.30.bn1.bias: requires_grad=True
# layer3.30.conv2.weight: requires_grad=False
# layer3.30.bn2.weight: requires_grad=True
# layer3.30.bn2.bias: requires_grad=True
# layer3.30.conv3.weight: requires_grad=False
# layer3.30.bn3.weight: requires_grad=True
# layer3.30.bn3.bias: requires_grad=True
# layer3.31.conv1.weight: requires_grad=False
# layer3.31.bn1.weight: requires_grad=True
# layer3.31.bn1.bias: requires_grad=True
# layer3.31.conv2.weight: requires_grad=False
# layer3.31.bn2.weight: requires_grad=True
# layer3.31.bn2.bias: requires_grad=True
# layer3.31.conv3.weight: requires_grad=False
# layer3.31.bn3.weight: requires_grad=True
# layer3.31.bn3.bias: requires_grad=True
# layer3.32.conv1.weight: requires_grad=False
# layer3.32.bn1.weight: requires_grad=True
# layer3.32.bn1.bias: requires_grad=True
# layer3.32.conv2.weight: requires_grad=False
# layer3.32.bn2.weight: requires_grad=True
# layer3.32.bn2.bias: requires_grad=True
# layer3.32.conv3.weight: requires_grad=False
# layer3.32.bn3.weight: requires_grad=True
# layer3.32.bn3.bias: requires_grad=True
# layer3.33.conv1.weight: requires_grad=False
# layer3.33.bn1.weight: requires_grad=True
# layer3.33.bn1.bias: requires_grad=True
# layer3.33.conv2.weight: requires_grad=False
# layer3.33.bn2.weight: requires_grad=True
# layer3.33.bn2.bias: requires_grad=True
# layer3.33.conv3.weight: requires_grad=False
# layer3.33.bn3.weight: requires_grad=True
# layer3.33.bn3.bias: requires_grad=True
# layer3.34.conv1.weight: requires_grad=False
# layer3.34.bn1.weight: requires_grad=True
# layer3.34.bn1.bias: requires_grad=True
# layer3.34.conv2.weight: requires_grad=False
# layer3.34.bn2.weight: requires_grad=True
# layer3.34.bn2.bias: requires_grad=True
# layer3.34.conv3.weight: requires_grad=False
# layer3.34.bn3.weight: requires_grad=True
# layer3.34.bn3.bias: requires_grad=True
# layer3.35.conv1.weight: requires_grad=False
# layer3.35.bn1.weight: requires_grad=True
# layer3.35.bn1.bias: requires_grad=True
# layer3.35.conv2.weight: requires_grad=False
# layer3.35.bn2.weight: requires_grad=True
# layer3.35.bn2.bias: requires_grad=True
# layer3.35.conv3.weight: requires_grad=False
# layer3.35.bn3.weight: requires_grad=True
# layer3.35.bn3.bias: requires_grad=True
# layer4.0.conv1.weight: requires_grad=True
# layer4.0.bn1.weight: requires_grad=True
# layer4.0.bn1.bias: requires_grad=True
# layer4.0.conv2.weight: requires_grad=True
# layer4.0.bn2.weight: requires_grad=True
# layer4.0.bn2.bias: requires_grad=True
# layer4.0.conv3.weight: requires_grad=True
# layer4.0.bn3.weight: requires_grad=True
# layer4.0.bn3.bias: requires_grad=True
# layer4.0.downsample.0.weight: requires_grad=True
# layer4.0.downsample.1.weight: requires_grad=True
# layer4.0.downsample.1.bias: requires_grad=True
# layer4.1.conv1.weight: requires_grad=True
# layer4.1.bn1.weight: requires_grad=True
# layer4.1.bn1.bias: requires_grad=True
# layer4.1.conv2.weight: requires_grad=True
# layer4.1.bn2.weight: requires_grad=True
# layer4.1.bn2.bias: requires_grad=True
# layer4.1.conv3.weight: requires_grad=True
# layer4.1.bn3.weight: requires_grad=True
# layer4.1.bn3.bias: requires_grad=True
# layer4.2.conv1.weight: requires_grad=True
# layer4.2.bn1.weight: requires_grad=True
# layer4.2.bn1.bias: requires_grad=True
# layer4.2.conv2.weight: requires_grad=True
# layer4.2.bn2.weight: requires_grad=True
# layer4.2.bn2.bias: requires_grad=True
# layer4.2.conv3.weight: requires_grad=True
# layer4.2.bn3.weight: requires_grad=True
# layer4.2.bn3.bias: requires_grad=True
# fc.0.weight: requires_grad=True
# fc.0.bias: requires_grad=True
# fc.3.weight: requires_grad=True
# fc.3.bias: requires_grad=True

# %%
if device.type == 'cuda':
    print(torch.cuda.get_device_name(0))
model.to(device)
# Out:
# Tesla T4
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (4): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (5): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (6): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (7): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (4): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (5): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (6): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (7): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (8): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (9): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (10): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (11): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (12): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (13): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (14): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (15): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (16): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (17): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (18): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (19): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (20): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (21): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (22): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (23): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (24): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (25): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (26): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (27): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (28): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (29): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (30): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (31): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (32): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (33): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (34): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (35): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Sequential(
#     (0): Linear(in_features=2048, out_features=256, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.5, inplace=False)
#     (3): Linear(in_features=256, out_features=10, bias=True)
#   )
# )

# %%
num_epochs = 8
train_losses = []
val_losses = []
train_accuracies = []
val_accuracies = []
train_times = []
val_times = []
best_model_path = 'best_model.pth'
best_val_accuracy = 0.0

for epoch in range(num_epochs):
    start_time = time.time()
    model.train()
    running_loss = 0.0
    correct_train = 0
    total_train = 0
    for inputs, labels in trainloader:
        inputs, labels = inputs.to(device), labels.to(device)

        optimizer.zero_grad()

        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item()
        _, predicted = torch.max(outputs, 1)
        total_train += labels.size(0)
        correct_train += (predicted == labels).sum().item()

    train_losses.append(running_loss / len(trainloader))
    train_accuracies.append(100 * correct_train / total_train)

    epoch_time = time.time() - start_time
    train_times.append(epoch_time)

    model.eval()
    running_val_loss = 0.0
    correct_val = 0
    total_val = 0
    val_start_time = time.time()
    with torch.no_grad():
        for inputs, labels in testloader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            running_val_loss += loss.item()
            _, predicted = torch.max(outputs, 1)
            total_val += labels.size(0)
            correct_val += (predicted == labels).sum().item()

    val_epoch_time = time.time() - val_start_time
    val_times.append(val_epoch_time)

    val_losses.append(running_val_loss / len(testloader))
    val_accuracies.append(100 * correct_val / total_val)
    scheduler.step(val_accuracies[-1])
    
    if val_accuracies[-1] > best_val_accuracy:
        best_val_accuracy = val_accuracies[-1]
        torch.save(model.state_dict(), best_model_path)
    
    
    
    print(f'Epoch {epoch+1}/{num_epochs}, '
          f'Loss: {train_losses[-1]:.4f}, '
          f'Val Loss: {val_losses[-1]:.4f}, '
          f'Accuracy: {train_accuracies[-1]:.2f}%, '
          f'Val Accuracy: {val_accuracies[-1]:.2f}%, '
          f'Train Time: {epoch_time:.2f}s, '
          f'Val Time: {val_epoch_time:.2f}s')

    
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(train_losses, label='Train Loss')
plt.plot(val_losses, label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Loss vs Epochs')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(train_accuracies, label='Train Accuracy')
plt.plot(val_accuracies, label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy (%)')
plt.title('Accuracy vs Epochs')
plt.legend()

plt.show()

avg_train_time = sum(train_times) / num_epochs
avg_val_time = sum(val_times) / num_epochs
print(f'Average Training Time per Epoch: {avg_train_time:.2f}s')
print(f'Average Validation Time per Epoch: {avg_val_time:.2f}s')
# Out:
# Epoch 1/8, Loss: 0.3933, Val Loss: 0.1410, Accuracy: 87.89%, Val Accuracy: 95.38%, Train Time: 999.80s, Val Time: 84.64s
# Epoch 2/8, Loss: 0.1760, Val Loss: 0.1360, Accuracy: 94.53%, Val Accuracy: 95.63%, Train Time: 1003.31s, Val Time: 84.64s
# Epoch 3/8, Loss: 0.1291, Val Loss: 0.1096, Accuracy: 96.08%, Val Accuracy: 96.48%, Train Time: 1003.25s, Val Time: 84.63s
# Epoch 4/8, Loss: 0.0911, Val Loss: 0.1070, Accuracy: 97.11%, Val Accuracy: 96.48%, Train Time: 1002.67s, Val Time: 84.67s
# Epoch 5/8, Loss: 0.0754, Val Loss: 0.1296, Accuracy: 97.61%, Val Accuracy: 96.19%, Train Time: 1003.43s, Val Time: 84.69s
# Epoch 6/8, Loss: 0.0637, Val Loss: 0.0990, Accuracy: 98.06%, Val Accuracy: 96.86%, Train Time: 1002.48s, Val Time: 84.52s
# Epoch 7/8, Loss: 0.0568, Val Loss: 0.0960, Accuracy: 98.14%, Val Accuracy: 97.19%, Train Time: 1000.48s, Val Time: 84.46s
# Epoch 8/8, Loss: 0.0459, Val Loss: 0.0967, Accuracy: 98.51%, Val Accuracy: 97.00%, Train Time: 1000.93s, Val Time: 84.47s
# Average Training Time per Epoch: 1002.04s
# Average Validation Time per Epoch: 84.59s

# %%
import torch
import torchvision
import matplotlib.pyplot as plt
import numpy as np

model.load_state_dict(torch.load(best_model_path))

def imshow(img):
    img = img / 2 + 0.5  
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()

dataiter = iter(trainloader)
images, labels = next(dataiter)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
images = images.to(device)

model.eval()
outputs = model(images)
_, predicted = torch.max(outputs, 1)

images = images.cpu()
predicted = predicted.cpu()

fig, axes = plt.subplots(2, 4, figsize=(12, 6))
fig.subplots_adjust(hspace=0.3)
axes = axes.ravel()

for i in range(8):
    image = images[i] / 2 + 0.5  
    npimg = image.numpy()
    axes[i].imshow(np.transpose(npimg, (1, 2, 0)))
    axes[i].set_title(f'Predicted: {trainloader.dataset.classes[predicted[i]]}', color='green' if predicted[i] == labels[i] else 'red')
    axes[i].axis('off')

plt.show()
